# %% [markdown]
# ## Define the Convolutional Neural Network
#
# After you've looked at the data you're working with and, in this case, know the shapes of the images and of the keypoints, you are ready to define a convolutional neural network that can *learn* from this data.
#
# In this notebook and in `models.py`, you will:
# 1. Define a CNN with images as input and keypoints as output
# 2. Construct the transformed FaceKeypointsDataset, just as before
# 3. Train the CNN on the training data, tracking loss
# 4. See how the trained model performs on test data
# 5. If necessary, modify the CNN structure and model hyperparameters, so that it performs *well* **\***
#
# **\*** What does *well* mean?
#
# "Well" means that the model's loss decreases during training **and**, when applied to test image data, the model produces keypoints that closely match the true keypoints of each face. And you'll see examples of this later in the notebook.
#
# ---

# %% [markdown]
# ## CNN Architecture
#
# Recall that CNN's are defined by a few types of layers:
# * Convolutional layers
# * Maxpooling layers
# * Fully-connected layers
#
# You are required to use the above layers and encouraged to add multiple convolutional layers and things like dropout layers that may prevent overfitting. You are also encouraged to look at literature on keypoint detection, such as [this paper](https://arxiv.org/pdf/1710.00977.pdf), to help you determine the structure of your network.
#
#
# ### TODO: Define your model in the provided file `models.py` file
#
# This file is mostly empty but contains the expected name and some TODO's for creating your model.
#
# ---

# %% [markdown]
# ## PyTorch Neural Nets
#
# To define a neural network in PyTorch, you define the layers of a model in the function `__init__` and define the feedforward behavior of a network that employs those initialized layers in the function `forward`, which takes in an input image tensor, `x`. The structure of this Net class is shown below and left for you to fill in.
#
# Note: During training, PyTorch will be able to perform backpropagation by keeping track of the network's feedforward behavior and using autograd to calculate the update to the weights in the network.
#
# #### Define the Layers in ` __init__`
# As a reminder, a conv/pool layer may be defined like this (in `__init__`):
# ```
# # 1 input image channel (for grayscale images), 32 output channels/feature maps, 3x3 square convolution kernel
# self.conv1 = nn.Conv2d(1, 32, 3)
#
# # maxpool that uses a square window of kernel_size=2, stride=2
# self.pool = nn.MaxPool2d(2, 2)
# ```
#
# #### Refer to Layers in `forward`
# Then referred to in the `forward` function like this, in which the conv1 layer has a ReLu activation applied to it before maxpooling is applied:
# ```
# x = self.pool(F.relu(self.conv1(x)))
# ```
#
# Best practice is to place any layers whose weights will change during the training process in `__init__` and refer to them in the `forward` function; any layers or functions that always behave in the same way, such as a pre-defined activation function, should appear *only* in the `forward` function.

# %% [markdown]
# #### Why models.py
#
# You are tasked with defining the network in the `models.py` file so that any models you define can be saved and loaded by name in different notebooks in this project directory. For example, by defining a CNN class called `Net` in `models.py`, you can then create that same architecture in this and other notebooks by simply importing the class and instantiating a model:
# ```
#     from models import Net
#     net = Net()
# ```

# %%
# load the data if you need to; if you have already loaded the data, you may comment this cell out
# -- DO NOT CHANGE THIS CELL -- #
# !mkdir /home/ubuntu/data
# !wget -P /home/ubuntu/data/ https://s3.amazonaws.com/video.udacity-data.com/topher/2018/May/5aea1b91_train-test-data/train-test-data.zip
# !unzip -n /home/ubuntu/data/train-test-data.zip -d /home/ubuntu/data
# Out:
# --2019-02-08 23:06:55--  https://s3.amazonaws.com/video.udacity-data.com/topher/2018/May/5aea1b91_train-test-data/train-test-data.zip
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.216.168.141
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.216.168.141|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 338613624 (323M) [application/zip]
# Saving to: '/home/ubuntu/data/train-test-data.zip'
#
# train-test-data.zip 100%[===================>] 322.93M  61.8MB/s    in 4.9s
#
# 2019-02-08 23:07:00 (66.4 MB/s) - '/home/ubuntu/data/train-test-data.zip' saved [338613624/338613624]
#
# Archive:  /home/ubuntu/data/train-test-data.zip
#    creating: /home/ubuntu/data/test/
#   inflating: /home/ubuntu/data/test/Abdel_Aziz_Al-Hakim_00.jpg
#   inflating: /home/ubuntu/data/test/Abdel_Aziz_Al-Hakim_01.jpg
#   inflating: /home/ubuntu/data/test/Abdel_Aziz_Al-Hakim_10.jpg
#   inflating: /home/ubuntu/data/test/Abdel_Aziz_Al-Hakim_11.jpg
#   inflating: /home/ubuntu/data/test/Abdel_Aziz_Al-Hakim_40.jpg
#   inflating: /home/ubuntu/data/test/Abdel_Aziz_Al-Hakim_41.jpg
#   inflating: /home/ubuntu/data/test/Abdullah_Gul_10.jpg
#   inflating: /home/ubuntu/data/test/Abdullah_Gul_11.jpg
#   inflating: /home/ubuntu/data/test/Abdullah_Gul_30.jpg
#   inflating: /home/ubuntu/data/test/Abdullah_Gul_31.jpg
#   inflating: /home/ubuntu/data/test/Abdullah_Gul_50.jpg
#   inflating: /home/ubuntu/data/test/Abdullah_Gul_51.jpg
#   inflating: /home/ubuntu/data/test/Adam_Sandler_00.jpg
#   inflating: /home/ubuntu/data/test/Adam_Sandler_01.jpg
#   inflating: /home/ubuntu/data/test/Adam_Sandler_10.jpg
#   inflating: /home/ubuntu/data/test/Adam_Sandler_11.jpg
#   inflating: /home/ubuntu/data/test/Adam_Sandler_40.jpg
#   inflating: /home/ubuntu/data/test/Adam_Sandler_41.jpg
#   inflating: /home/ubuntu/data/test/Adrian_Nastase_10.jpg
#   inflating: /home/ubuntu/data/test/Adrian_Nastase_11.jpg
#   inflating: /home/ubuntu/data/test/Adrian_Nastase_40.jpg
#   inflating: /home/ubuntu/data/test/Adrian_Nastase_41.jpg
#   inflating: /home/ubuntu/data/test/Adrian_Nastase_50.jpg
#   inflating: /home/ubuntu/data/test/Adrian_Nastase_51.jpg
#   inflating: /home/ubuntu/data/test/Agbani_Darego_00.jpg
#   inflating: /home/ubuntu/data/test/Agbani_Darego_01.jpg
#   inflating: /home/ubuntu/data/test/Agbani_Darego_20.jpg
#   inflating: /home/ubuntu/data/test/Agbani_Darego_21.jpg
#   inflating: /home/ubuntu/data/test/Agbani_Darego_40.jpg
#   inflating: /home/ubuntu/data/test/Agbani_Darego_41.jpg
#   inflating: /home/ubuntu/data/test/Agbani_Darego_50.jpg
#   inflating: /home/ubuntu/data/test/Agbani_Darego_51.jpg
#   inflating: /home/ubuntu/data/test/Agnes_Bruckner_00.jpg
#   inflating: /home/ubuntu/data/test/Agnes_Bruckner_01.jpg
#   inflating: /home/ubuntu/data/test/Agnes_Bruckner_10.jpg
#   inflating: /home/ubuntu/data/test/Agnes_Bruckner_11.jpg
#   inflating: /home/ubuntu/data/test/Agnes_Bruckner_20.jpg
#   inflating: /home/ubuntu/data/test/Agnes_Bruckner_21.jpg
#   inflating: /home/ubuntu/data/test/Agnes_Bruckner_40.jpg
#   inflating: /home/ubuntu/data/test/Agnes_Bruckner_41.jpg
#   inflating: /home/ubuntu/data/test/Ahmad_Masood_00.jpg
#   inflating: /home/ubuntu/data/test/Ahmad_Masood_01.jpg
#   inflating: /home/ubuntu/data/test/Ahmad_Masood_30.jpg
#   inflating: /home/ubuntu/data/test/Ahmad_Masood_31.jpg
#   inflating: /home/ubuntu/data/test/Ahmad_Masood_40.jpg
#   inflating: /home/ubuntu/data/test/Ahmad_Masood_41.jpg
#   inflating: /home/ubuntu/data/test/Ahmed_Ahmed_00.jpg
#   inflating: /home/ubuntu/data/test/Ahmed_Ahmed_01.jpg
#   inflating: /home/ubuntu/data/test/Ahmed_Ahmed_10.jpg
#   inflating: /home/ubuntu/data/test/Ahmed_Ahmed_11.jpg
#   inflating: /home/ubuntu/data/test/Ahmed_Ahmed_40.jpg
#   inflating: /home/ubuntu/data/test/Ahmed_Ahmed_41.jpg
#   inflating: /home/ubuntu/data/test/Ahmed_Ahmed_50.jpg
#   inflating: /home/ubuntu/data/test/Ahmed_Ahmed_51.jpg
#   inflating: /home/ubuntu/data/test/Aidan_Quinn_00.jpg
#   inflating: /home/ubuntu/data/test/Aidan_Quinn_01.jpg
#   inflating: /home/ubuntu/data/test/Aidan_Quinn_10.jpg
#   inflating: /home/ubuntu/data/test/Aidan_Quinn_11.jpg
#   inflating: /home/ubuntu/data/test/Aidan_Quinn_20.jpg
#   inflating: /home/ubuntu/data/test/Aidan_Quinn_21.jpg
#   inflating: /home/ubuntu/data/test/Aidan_Quinn_30.jpg
#   inflating: /home/ubuntu/data/test/Aidan_Quinn_31.jpg
#   inflating: /home/ubuntu/data/test/Aishwarya_Rai_00.jpg
#   inflating: /home/ubuntu/data/test/Aishwarya_Rai_01.jpg
#   inflating: /home/ubuntu/data/test/Aishwarya_Rai_10.jpg
#   inflating: /home/ubuntu/data/test/Aishwarya_Rai_11.jpg
#   inflating: /home/ubuntu/data/test/Aishwarya_Rai_40.jpg
#   inflating: /home/ubuntu/data/test/Aishwarya_Rai_41.jpg
#   inflating: /home/ubuntu/data/test/Aishwarya_Rai_50.jpg
#   inflating: /home/ubuntu/data/test/Aishwarya_Rai_51.jpg
#   inflating: /home/ubuntu/data/test/Albert_Brooks_00.jpg
#   inflating: /home/ubuntu/data/test/Albert_Brooks_01.jpg
#   inflating: /home/ubuntu/data/test/Albert_Brooks_10.jpg
#   inflating: /home/ubuntu/data/test/Albert_Brooks_11.jpg
#   inflating: /home/ubuntu/data/test/Albert_Brooks_30.jpg
#   inflating: /home/ubuntu/data/test/Albert_Brooks_31.jpg
#   inflating: /home/ubuntu/data/test/Alejandro_Toledo_10.jpg
#   inflating: /home/ubuntu/data/test/Alejandro_Toledo_11.jpg
#   inflating: /home/ubuntu/data/test/Alejandro_Toledo_30.jpg
#   inflating: /home/ubuntu/data/test/Alejandro_Toledo_31.jpg
#   inflating: /home/ubuntu/data/test/Alejandro_Toledo_50.jpg
#   inflating: /home/ubuntu/data/test/Alejandro_Toledo_51.jpg
#   inflating: /home/ubuntu/data/test/Aleksander_Kwasniewski_00.jpg
#   inflating: /home/ubuntu/data/test/Aleksander_Kwasniewski_01.jpg
#   inflating: /home/ubuntu/data/test/Aleksander_Kwasniewski_10.jpg
#   inflating: /home/ubuntu/data/test/Aleksander_Kwasniewski_11.jpg
#   inflating: /home/ubuntu/data/test/Aleksander_Kwasniewski_20.jpg
#   inflating: /home/ubuntu/data/test/Aleksander_Kwasniewski_21.jpg
#   inflating: /home/ubuntu/data/test/Aleksander_Kwasniewski_30.jpg
#   inflating: /home/ubuntu/data/test/Aleksander_Kwasniewski_31.jpg
#   inflating: /home/ubuntu/data/test/Alex_Ferguson_00.jpg
#   inflating: /home/ubuntu/data/test/Alex_Ferguson_01.jpg
#   inflating: /home/ubuntu/data/test/Alex_Ferguson_10.jpg
#   inflating: /home/ubuntu/data/test/Alex_Ferguson_11.jpg
#   inflating: /home/ubuntu/data/test/Alex_Ferguson_50.jpg
#   inflating: /home/ubuntu/data/test/Alex_Ferguson_51.jpg
#   inflating: /home/ubuntu/data/test/Alexandra_Pelosi_00.jpg
#   inflating: /home/ubuntu/data/test/Alexandra_Pelosi_01.jpg
#   inflating: /home/ubuntu/data/test/Alexandra_Pelosi_10.jpg
#   inflating: /home/ubuntu/data/test/Alexandra_Pelosi_11.jpg
#   inflating: /home/ubuntu/data/test/Alexandra_Pelosi_30.jpg
#   inflating: /home/ubuntu/data/test/Alexandra_Pelosi_31.jpg
#   inflating: /home/ubuntu/data/test/Alfredo_di_Stefano_00.jpg
#   inflating: /home/ubuntu/data/test/Alfredo_di_Stefano_01.jpg
#   inflating: /home/ubuntu/data/test/Alfredo_di_Stefano_20.jpg
#   inflating: /home/ubuntu/data/test/Alfredo_di_Stefano_21.jpg
#   inflating: /home/ubuntu/data/test/Alfredo_di_Stefano_50.jpg
#   inflating: /home/ubuntu/data/test/Alfredo_di_Stefano_51.jpg
#   inflating: /home/ubuntu/data/test/Ali_Abbas_20.jpg
#   inflating: /home/ubuntu/data/test/Ali_Abbas_21.jpg
#   inflating: /home/ubuntu/data/test/Ali_Abbas_30.jpg
#   inflating: /home/ubuntu/data/test/Ali_Abbas_31.jpg
#   inflating: /home/ubuntu/data/test/Ali_Abbas_40.jpg
#   inflating: /home/ubuntu/data/test/Ali_Abbas_41.jpg
#   inflating: /home/ubuntu/data/test/Ali_Abbas_50.jpg
#   inflating: /home/ubuntu/data/test/Ali_Abbas_51.jpg
#   inflating: /home/ubuntu/data/test/Alicia_Silverstone_00.jpg
#   inflating: /home/ubuntu/data/test/Alicia_Silverstone_01.jpg
#   inflating: /home/ubuntu/data/test/Alicia_Silverstone_10.jpg
#   inflating: /home/ubuntu/data/test/Alicia_Silverstone_11.jpg
#   inflating: /home/ubuntu/data/test/Alicia_Silverstone_20.jpg
#   inflating: /home/ubuntu/data/test/Alicia_Silverstone_21.jpg
#   inflating: /home/ubuntu/data/test/Alicia_Silverstone_50.jpg
#   inflating: /home/ubuntu/data/test/Alicia_Silverstone_51.jpg
#   inflating: /home/ubuntu/data/test/Alma_Powell_00.jpg
#   inflating: /home/ubuntu/data/test/Alma_Powell_01.jpg
#   inflating: /home/ubuntu/data/test/Alma_Powell_10.jpg
#   inflating: /home/ubuntu/data/test/Alma_Powell_11.jpg
#   inflating: /home/ubuntu/data/test/Alma_Powell_40.jpg
#   inflating: /home/ubuntu/data/test/Alma_Powell_41.jpg
#   inflating: /home/ubuntu/data/test/Alma_Powell_50.jpg
#   inflating: /home/ubuntu/data/test/Alma_Powell_51.jpg
#   inflating: /home/ubuntu/data/test/Alvaro_Silva_Calderon_00.jpg
#   inflating: /home/ubuntu/data/test/Alvaro_Silva_Calderon_01.jpg
#   inflating: /home/ubuntu/data/test/Alvaro_Silva_Calderon_10.jpg
#   inflating: /home/ubuntu/data/test/Alvaro_Silva_Calderon_11.jpg
#   inflating: /home/ubuntu/data/test/Alvaro_Silva_Calderon_20.jpg
#   inflating: /home/ubuntu/data/test/Alvaro_Silva_Calderon_21.jpg
#   inflating: /home/ubuntu/data/test/Alvaro_Silva_Calderon_30.jpg
#   inflating: /home/ubuntu/data/test/Alvaro_Silva_Calderon_31.jpg
#   inflating: /home/ubuntu/data/test/Amelia_Vega_10.jpg
#   inflating: /home/ubuntu/data/test/Amelia_Vega_11.jpg
#   inflating: /home/ubuntu/data/test/Amelia_Vega_20.jpg
#   inflating: /home/ubuntu/data/test/Amelia_Vega_21.jpg
#   inflating: /home/ubuntu/data/test/Amelia_Vega_30.jpg
#   inflating: /home/ubuntu/data/test/Amelia_Vega_31.jpg
#   inflating: /home/ubuntu/data/test/Amelia_Vega_40.jpg
#   inflating: /home/ubuntu/data/test/Amelia_Vega_41.jpg
#   inflating: /home/ubuntu/data/test/Amy_Brenneman_10.jpg
#   inflating: /home/ubuntu/data/test/Amy_Brenneman_11.jpg
#   inflating: /home/ubuntu/data/test/Amy_Brenneman_30.jpg
#   inflating: /home/ubuntu/data/test/Amy_Brenneman_31.jpg
#   inflating: /home/ubuntu/data/test/Amy_Brenneman_50.jpg
#   inflating: /home/ubuntu/data/test/Amy_Brenneman_51.jpg
#   inflating: /home/ubuntu/data/test/Andrea_Bocelli_10.jpg
#   inflating: /home/ubuntu/data/test/Andrea_Bocelli_11.jpg
#   inflating: /home/ubuntu/data/test/Andrea_Bocelli_20.jpg
#   inflating: /home/ubuntu/data/test/Andrea_Bocelli_21.jpg
#   inflating: /home/ubuntu/data/test/Andrea_Bocelli_30.jpg
#   inflating: /home/ubuntu/data/test/Andrea_Bocelli_31.jpg
#   inflating: /home/ubuntu/data/test/Andy_Roddick_20.jpg
#   inflating: /home/ubuntu/data/test/Andy_Roddick_21.jpg
#   inflating: /home/ubuntu/data/test/Andy_Roddick_40.jpg
#   inflating: /home/ubuntu/data/test/Andy_Roddick_41.jpg
#   inflating: /home/ubuntu/data/test/Andy_Roddick_50.jpg
#   inflating: /home/ubuntu/data/test/Andy_Roddick_51.jpg
#   inflating: /home/ubuntu/data/test/Andy_Rooney_10.jpg
#   inflating: /home/ubuntu/data/test/Andy_Rooney_11.jpg
#   inflating: /home/ubuntu/data/test/Andy_Rooney_20.jpg
#   inflating: /home/ubuntu/data/test/Andy_Rooney_21.jpg
#   inflating: /home/ubuntu/data/test/Andy_Rooney_50.jpg
#   inflating: /home/ubuntu/data/test/Andy_Rooney_51.jpg
#   inflating: /home/ubuntu/data/test/Angel_Lockward_30.jpg
#   inflating: /home/ubuntu/data/test/Angel_Lockward_31.jpg
#   inflating: /home/ubuntu/data/test/Angel_Lockward_40.jpg
#   inflating: /home/ubuntu/data/test/Angel_Lockward_41.jpg
#   inflating: /home/ubuntu/data/test/Angel_Lockward_50.jpg
#   inflating: /home/ubuntu/data/test/Angel_Lockward_51.jpg
#   inflating: /home/ubuntu/data/test/Angela_Bassett_20.jpg
#   inflating: /home/ubuntu/data/test/Angela_Bassett_21.jpg
#   inflating: /home/ubuntu/data/test/Angela_Bassett_30.jpg
#   inflating: /home/ubuntu/data/test/Angela_Bassett_31.jpg
#   inflating: /home/ubuntu/data/test/Angela_Bassett_40.jpg
#   inflating: /home/ubuntu/data/test/Angela_Bassett_41.jpg
#   inflating: /home/ubuntu/data/test/Angelo_Reyes_20.jpg
#   inflating: /home/ubuntu/data/test/Angelo_Reyes_21.jpg
#   inflating: /home/ubuntu/data/test/Angelo_Reyes_30.jpg
#   inflating: /home/ubuntu/data/test/Angelo_Reyes_31.jpg
#   inflating: /home/ubuntu/data/test/Angelo_Reyes_50.jpg
#   inflating: /home/ubuntu/data/test/Angelo_Reyes_51.jpg
#   inflating: /home/ubuntu/data/test/Baburam_Bhattari_00.jpg
#   inflating: /home/ubuntu/data/test/Baburam_Bhattari_01.jpg
#   inflating: /home/ubuntu/data/test/Baburam_Bhattari_20.jpg
#   inflating: /home/ubuntu/data/test/Baburam_Bhattari_21.jpg
#   inflating: /home/ubuntu/data/test/Baburam_Bhattari_30.jpg
#   inflating: /home/ubuntu/data/test/Baburam_Bhattari_31.jpg
#   inflating: /home/ubuntu/data/test/Barbara_Bodine_00.jpg
#   inflating: /home/ubuntu/data/test/Barbara_Bodine_01.jpg
#   inflating: /home/ubuntu/data/test/Barbara_Bodine_20.jpg
#   inflating: /home/ubuntu/data/test/Barbara_Bodine_21.jpg
#   inflating: /home/ubuntu/data/test/Barbara_Bodine_40.jpg
#   inflating: /home/ubuntu/data/test/Barbara_Bodine_41.jpg
#   inflating: /home/ubuntu/data/test/Barbara_Bodine_50.jpg
#   inflating: /home/ubuntu/data/test/Barbara_Bodine_51.jpg
#   inflating: /home/ubuntu/data/test/Barbara_Boxer_10.jpg
#   inflating: /home/ubuntu/data/test/Barbara_Boxer_11.jpg
#   inflating: /home/ubuntu/data/test/Barbara_Boxer_40.jpg
#   inflating: /home/ubuntu/data/test/Barbara_Boxer_41.jpg
#   inflating: /home/ubuntu/data/test/Barbara_Boxer_50.jpg
#   inflating: /home/ubuntu/data/test/Barbara_Boxer_51.jpg
#   inflating: /home/ubuntu/data/test/Barbara_Walters_00.jpg
#   inflating: /home/ubuntu/data/test/Barbara_Walters_01.jpg
#   inflating: /home/ubuntu/data/test/Barbara_Walters_20.jpg
#   inflating: /home/ubuntu/data/test/Barbara_Walters_21.jpg
#   inflating: /home/ubuntu/data/test/Barbara_Walters_40.jpg
#   inflating: /home/ubuntu/data/test/Barbara_Walters_41.jpg
#   inflating: /home/ubuntu/data/test/Barbara_Walters_50.jpg
#   inflating: /home/ubuntu/data/test/Barbara_Walters_51.jpg
#   inflating: /home/ubuntu/data/test/Barry_Alvarez_00.jpg
#   inflating: /home/ubuntu/data/test/Barry_Alvarez_01.jpg
#   inflating: /home/ubuntu/data/test/Barry_Alvarez_10.jpg
#   inflating: /home/ubuntu/data/test/Barry_Alvarez_11.jpg
#   inflating: /home/ubuntu/data/test/Barry_Alvarez_20.jpg
#   inflating: /home/ubuntu/data/test/Barry_Alvarez_21.jpg
#   inflating: /home/ubuntu/data/test/Barry_Alvarez_30.jpg
#   inflating: /home/ubuntu/data/test/Barry_Alvarez_31.jpg
#   inflating: /home/ubuntu/data/test/Ben_Kingsley_10.jpg
#   inflating: /home/ubuntu/data/test/Ben_Kingsley_11.jpg
#   inflating: /home/ubuntu/data/test/Ben_Kingsley_20.jpg
#   inflating: /home/ubuntu/data/test/Ben_Kingsley_21.jpg
#   inflating: /home/ubuntu/data/test/Ben_Kingsley_50.jpg
#   inflating: /home/ubuntu/data/test/Ben_Kingsley_51.jpg
#   inflating: /home/ubuntu/data/test/Ben_Stein_10.jpg
#   inflating: /home/ubuntu/data/test/Ben_Stein_11.jpg
#   inflating: /home/ubuntu/data/test/Ben_Stein_30.jpg
#   inflating: /home/ubuntu/data/test/Ben_Stein_31.jpg
#   inflating: /home/ubuntu/data/test/Ben_Stein_40.jpg
#   inflating: /home/ubuntu/data/test/Ben_Stein_41.jpg
#   inflating: /home/ubuntu/data/test/Ben_Stein_50.jpg
#   inflating: /home/ubuntu/data/test/Ben_Stein_51.jpg
#   inflating: /home/ubuntu/data/test/Benedita_da_Silva_10.jpg
#   inflating: /home/ubuntu/data/test/Benedita_da_Silva_11.jpg
#   inflating: /home/ubuntu/data/test/Benedita_da_Silva_20.jpg
#   inflating: /home/ubuntu/data/test/Benedita_da_Silva_21.jpg
#   inflating: /home/ubuntu/data/test/Benedita_da_Silva_50.jpg
#   inflating: /home/ubuntu/data/test/Benedita_da_Silva_51.jpg
#   inflating: /home/ubuntu/data/test/Benjamin_McKenzie_30.jpg
#   inflating: /home/ubuntu/data/test/Benjamin_McKenzie_31.jpg
#   inflating: /home/ubuntu/data/test/Benjamin_McKenzie_40.jpg
#   inflating: /home/ubuntu/data/test/Benjamin_McKenzie_41.jpg
#   inflating: /home/ubuntu/data/test/Benjamin_McKenzie_50.jpg
#   inflating: /home/ubuntu/data/test/Benjamin_McKenzie_51.jpg
#   inflating: /home/ubuntu/data/test/Benjamin_Netanyahu_00.jpg
#   inflating: /home/ubuntu/data/test/Benjamin_Netanyahu_01.jpg
#   inflating: /home/ubuntu/data/test/Benjamin_Netanyahu_10.jpg
#   inflating: /home/ubuntu/data/test/Benjamin_Netanyahu_11.jpg
#   inflating: /home/ubuntu/data/test/Benjamin_Netanyahu_30.jpg
#   inflating: /home/ubuntu/data/test/Benjamin_Netanyahu_31.jpg
#   inflating: /home/ubuntu/data/test/Benjamin_Netanyahu_40.jpg
#   inflating: /home/ubuntu/data/test/Benjamin_Netanyahu_41.jpg
#   inflating: /home/ubuntu/data/test/Beyonce_Knowles_00.jpg
#   inflating: /home/ubuntu/data/test/Beyonce_Knowles_01.jpg
#   inflating: /home/ubuntu/data/test/Beyonce_Knowles_30.jpg
#   inflating: /home/ubuntu/data/test/Beyonce_Knowles_31.jpg
#   inflating: /home/ubuntu/data/test/Beyonce_Knowles_50.jpg
#   inflating: /home/ubuntu/data/test/Beyonce_Knowles_51.jpg
#   inflating: /home/ubuntu/data/test/Bianca_Jagger_20.jpg
#   inflating: /home/ubuntu/data/test/Bianca_Jagger_21.jpg
#   inflating: /home/ubuntu/data/test/Bianca_Jagger_30.jpg
#   inflating: /home/ubuntu/data/test/Bianca_Jagger_31.jpg
#   inflating: /home/ubuntu/data/test/Bianca_Jagger_40.jpg
#   inflating: /home/ubuntu/data/test/Bianca_Jagger_41.jpg
#   inflating: /home/ubuntu/data/test/Biljana_Plavsic_00.jpg
#   inflating: /home/ubuntu/data/test/Biljana_Plavsic_01.jpg
#   inflating: /home/ubuntu/data/test/Biljana_Plavsic_10.jpg
#   inflating: /home/ubuntu/data/test/Biljana_Plavsic_11.jpg
#   inflating: /home/ubuntu/data/test/Biljana_Plavsic_30.jpg
#   inflating: /home/ubuntu/data/test/Biljana_Plavsic_31.jpg
#   inflating: /home/ubuntu/data/test/Bill_Bradley_10.jpg
#   inflating: /home/ubuntu/data/test/Bill_Bradley_11.jpg
#   inflating: /home/ubuntu/data/test/Bill_Bradley_30.jpg
#   inflating: /home/ubuntu/data/test/Bill_Bradley_31.jpg
#   inflating: /home/ubuntu/data/test/Bill_Bradley_50.jpg
#   inflating: /home/ubuntu/data/test/Bill_Bradley_51.jpg
#   inflating: /home/ubuntu/data/test/Bill_Clinton_00.jpg
#   inflating: /home/ubuntu/data/test/Bill_Clinton_01.jpg
#   inflating: /home/ubuntu/data/test/Bill_Clinton_10.jpg
#   inflating: /home/ubuntu/data/test/Bill_Clinton_11.jpg
#   inflating: /home/ubuntu/data/test/Bill_Clinton_50.jpg
#   inflating: /home/ubuntu/data/test/Bill_Clinton_51.jpg
#   inflating: /home/ubuntu/data/test/Bill_Frist_00.jpg
#   inflating: /home/ubuntu/data/test/Bill_Frist_01.jpg
#   inflating: /home/ubuntu/data/test/Bill_Frist_10.jpg
#   inflating: /home/ubuntu/data/test/Bill_Frist_11.jpg
#   inflating: /home/ubuntu/data/test/Bill_Frist_20.jpg
#   inflating: /home/ubuntu/data/test/Bill_Frist_21.jpg
#   inflating: /home/ubuntu/data/test/Cameron_Diaz_20.jpg
#   inflating: /home/ubuntu/data/test/Cameron_Diaz_21.jpg
#   inflating: /home/ubuntu/data/test/Cameron_Diaz_40.jpg
#   inflating: /home/ubuntu/data/test/Cameron_Diaz_41.jpg
#   inflating: /home/ubuntu/data/test/Cameron_Diaz_50.jpg
#   inflating: /home/ubuntu/data/test/Cameron_Diaz_51.jpg
#   inflating: /home/ubuntu/data/test/Carey_Lowell_00.jpg
#   inflating: /home/ubuntu/data/test/Carey_Lowell_01.jpg
#   inflating: /home/ubuntu/data/test/Carey_Lowell_20.jpg
#   inflating: /home/ubuntu/data/test/Carey_Lowell_21.jpg
#   inflating: /home/ubuntu/data/test/Carey_Lowell_30.jpg
#   inflating: /home/ubuntu/data/test/Carey_Lowell_31.jpg
#   inflating: /home/ubuntu/data/test/Carla_Gugino_10.jpg
#   inflating: /home/ubuntu/data/test/Carla_Gugino_11.jpg
#   inflating: /home/ubuntu/data/test/Carla_Gugino_30.jpg
#   inflating: /home/ubuntu/data/test/Carla_Gugino_31.jpg
#   inflating: /home/ubuntu/data/test/Carla_Gugino_50.jpg
#   inflating: /home/ubuntu/data/test/Carla_Gugino_51.jpg
#   inflating: /home/ubuntu/data/test/Carlo_Azeglio_Ciampi_00.jpg
#   inflating: /home/ubuntu/data/test/Carlo_Azeglio_Ciampi_01.jpg
#   inflating: /home/ubuntu/data/test/Carlo_Azeglio_Ciampi_10.jpg
#   inflating: /home/ubuntu/data/test/Carlo_Azeglio_Ciampi_11.jpg
#   inflating: /home/ubuntu/data/test/Carlo_Azeglio_Ciampi_20.jpg
#   inflating: /home/ubuntu/data/test/Carlo_Azeglio_Ciampi_21.jpg
#   inflating: /home/ubuntu/data/test/Carlo_Azeglio_Ciampi_50.jpg
#   inflating: /home/ubuntu/data/test/Carlo_Azeglio_Ciampi_51.jpg
#   inflating: /home/ubuntu/data/test/Carlos_Ghosn_10.jpg
#   inflating: /home/ubuntu/data/test/Carlos_Ghosn_11.jpg
#   inflating: /home/ubuntu/data/test/Carlos_Ghosn_20.jpg
#   inflating: /home/ubuntu/data/test/Carlos_Ghosn_21.jpg
#   inflating: /home/ubuntu/data/test/Carlos_Ghosn_40.jpg
#   inflating: /home/ubuntu/data/test/Carlos_Ghosn_41.jpg
#   inflating: /home/ubuntu/data/test/Carlos_Iturgaitz_10.jpg
#   inflating: /home/ubuntu/data/test/Carlos_Iturgaitz_11.jpg
#   inflating: /home/ubuntu/data/test/Carlos_Iturgaitz_20.jpg
#   inflating: /home/ubuntu/data/test/Carlos_Iturgaitz_21.jpg
#   inflating: /home/ubuntu/data/test/Carlos_Iturgaitz_30.jpg
#   inflating: /home/ubuntu/data/test/Carlos_Iturgaitz_31.jpg
#   inflating: /home/ubuntu/data/test/Carlos_Iturgaitz_50.jpg
#   inflating: /home/ubuntu/data/test/Carlos_Iturgaitz_51.jpg
#   inflating: /home/ubuntu/data/test/Carlos_Menem_00.jpg
#   inflating: /home/ubuntu/data/test/Carlos_Menem_01.jpg
#   inflating: /home/ubuntu/data/test/Carlos_Menem_20.jpg
#   inflating: /home/ubuntu/data/test/Carlos_Menem_21.jpg
#   inflating: /home/ubuntu/data/test/Carlos_Menem_30.jpg
#   inflating: /home/ubuntu/data/test/Carlos_Menem_31.jpg
#   inflating: /home/ubuntu/data/test/Carlos_Queiroz_00.jpg
#   inflating: /home/ubuntu/data/test/Carlos_Queiroz_01.jpg
#   inflating: /home/ubuntu/data/test/Carlos_Queiroz_10.jpg
#   inflating: /home/ubuntu/data/test/Carlos_Queiroz_11.jpg
#   inflating: /home/ubuntu/data/test/Carlos_Queiroz_50.jpg
#   inflating: /home/ubuntu/data/test/Carlos_Queiroz_51.jpg
#   inflating: /home/ubuntu/data/test/Carrie-Anne_Moss_00.jpg
#   inflating: /home/ubuntu/data/test/Carrie-Anne_Moss_01.jpg
#   inflating: /home/ubuntu/data/test/Carrie-Anne_Moss_10.jpg
#   inflating: /home/ubuntu/data/test/Carrie-Anne_Moss_11.jpg
#   inflating: /home/ubuntu/data/test/Carrie-Anne_Moss_50.jpg
#   inflating: /home/ubuntu/data/test/Carrie-Anne_Moss_51.jpg
#   inflating: /home/ubuntu/data/test/Catriona_Le_May_Doan_10.jpg
#   inflating: /home/ubuntu/data/test/Catriona_Le_May_Doan_11.jpg
#   inflating: /home/ubuntu/data/test/Catriona_Le_May_Doan_30.jpg
#   inflating: /home/ubuntu/data/test/Catriona_Le_May_Doan_31.jpg
#   inflating: /home/ubuntu/data/test/Catriona_Le_May_Doan_40.jpg
#   inflating: /home/ubuntu/data/test/Catriona_Le_May_Doan_41.jpg
#   inflating: /home/ubuntu/data/test/Cecilia_Cheung_00.jpg
#   inflating: /home/ubuntu/data/test/Cecilia_Cheung_01.jpg
#   inflating: /home/ubuntu/data/test/Cecilia_Cheung_10.jpg
#   inflating: /home/ubuntu/data/test/Cecilia_Cheung_11.jpg
#   inflating: /home/ubuntu/data/test/Cecilia_Cheung_20.jpg
#   inflating: /home/ubuntu/data/test/Cecilia_Cheung_21.jpg
#   inflating: /home/ubuntu/data/test/Cecilia_Cheung_50.jpg
#   inflating: /home/ubuntu/data/test/Cecilia_Cheung_51.jpg
#   inflating: /home/ubuntu/data/test/Celso_Amorim_10.jpg
#   inflating: /home/ubuntu/data/test/Celso_Amorim_11.jpg
#   inflating: /home/ubuntu/data/test/Celso_Amorim_40.jpg
#   inflating: /home/ubuntu/data/test/Celso_Amorim_41.jpg
#   inflating: /home/ubuntu/data/test/Celso_Amorim_50.jpg
#   inflating: /home/ubuntu/data/test/Celso_Amorim_51.jpg
#   inflating: /home/ubuntu/data/test/Celso_Lafer_00.jpg
#   inflating: /home/ubuntu/data/test/Celso_Lafer_01.jpg
#   inflating: /home/ubuntu/data/test/Celso_Lafer_10.jpg
#   inflating: /home/ubuntu/data/test/Celso_Lafer_11.jpg
#   inflating: /home/ubuntu/data/test/Celso_Lafer_20.jpg
#   inflating: /home/ubuntu/data/test/Celso_Lafer_21.jpg
#   inflating: /home/ubuntu/data/test/Chadha_Gurinder_10.jpg
#   inflating: /home/ubuntu/data/test/Chadha_Gurinder_11.jpg
#   inflating: /home/ubuntu/data/test/Chadha_Gurinder_20.jpg
#   inflating: /home/ubuntu/data/test/Chadha_Gurinder_21.jpg
#   inflating: /home/ubuntu/data/test/Chadha_Gurinder_50.jpg
#   inflating: /home/ubuntu/data/test/Chadha_Gurinder_51.jpg
#   inflating: /home/ubuntu/data/test/Charles_Bronson_00.jpg
#   inflating: /home/ubuntu/data/test/Charles_Bronson_01.jpg
#   inflating: /home/ubuntu/data/test/Charles_Bronson_10.jpg
#   inflating: /home/ubuntu/data/test/Charles_Bronson_11.jpg
#   inflating: /home/ubuntu/data/test/Charles_Bronson_50.jpg
#   inflating: /home/ubuntu/data/test/Charles_Bronson_51.jpg
#   inflating: /home/ubuntu/data/test/Charlie_Coles_00.jpg
#   inflating: /home/ubuntu/data/test/Charlie_Coles_01.jpg
#   inflating: /home/ubuntu/data/test/Charlie_Coles_10.jpg
#   inflating: /home/ubuntu/data/test/Charlie_Coles_11.jpg
#   inflating: /home/ubuntu/data/test/Charlie_Coles_20.jpg
#   inflating: /home/ubuntu/data/test/Charlie_Coles_21.jpg
#   inflating: /home/ubuntu/data/test/Charlize_Theron_10.jpg
#   inflating: /home/ubuntu/data/test/Charlize_Theron_11.jpg
#   inflating: /home/ubuntu/data/test/Charlize_Theron_30.jpg
#   inflating: /home/ubuntu/data/test/Charlize_Theron_31.jpg
#   inflating: /home/ubuntu/data/test/Charlize_Theron_50.jpg
#   inflating: /home/ubuntu/data/test/Charlize_Theron_51.jpg
#   inflating: /home/ubuntu/data/test/Charlotte_Casiraghi_00.jpg
#   inflating: /home/ubuntu/data/test/Charlotte_Casiraghi_01.jpg
#   inflating: /home/ubuntu/data/test/Charlotte_Casiraghi_10.jpg
#   inflating: /home/ubuntu/data/test/Charlotte_Casiraghi_11.jpg
#   inflating: /home/ubuntu/data/test/Charlotte_Casiraghi_20.jpg
#   inflating: /home/ubuntu/data/test/Charlotte_Casiraghi_21.jpg
#   inflating: /home/ubuntu/data/test/Charlotte_Rampling_00.jpg
#   inflating: /home/ubuntu/data/test/Charlotte_Rampling_01.jpg
#   inflating: /home/ubuntu/data/test/Charlotte_Rampling_30.jpg
#   inflating: /home/ubuntu/data/test/Charlotte_Rampling_31.jpg
#   inflating: /home/ubuntu/data/test/Charlotte_Rampling_40.jpg
#   inflating: /home/ubuntu/data/test/Charlotte_Rampling_41.jpg
#   inflating: /home/ubuntu/data/test/Charlotte_Rampling_50.jpg
#   inflating: /home/ubuntu/data/test/Charlotte_Rampling_51.jpg
#   inflating: /home/ubuntu/data/test/Cherie_Blair_00.jpg
#   inflating: /home/ubuntu/data/test/Cherie_Blair_01.jpg
#   inflating: /home/ubuntu/data/test/Cherie_Blair_20.jpg
#   inflating: /home/ubuntu/data/test/Cherie_Blair_21.jpg
#   inflating: /home/ubuntu/data/test/Cherie_Blair_30.jpg
#   inflating: /home/ubuntu/data/test/Cherie_Blair_31.jpg
#   inflating: /home/ubuntu/data/test/Cherie_Blair_40.jpg
#   inflating: /home/ubuntu/data/test/Cherie_Blair_41.jpg
#   inflating: /home/ubuntu/data/test/Chita_Rivera_00.jpg
#   inflating: /home/ubuntu/data/test/Chita_Rivera_01.jpg
#   inflating: /home/ubuntu/data/test/Chita_Rivera_10.jpg
#   inflating: /home/ubuntu/data/test/Chita_Rivera_11.jpg
#   inflating: /home/ubuntu/data/test/Chita_Rivera_30.jpg
#   inflating: /home/ubuntu/data/test/Chita_Rivera_31.jpg
#   inflating: /home/ubuntu/data/test/Chris_Cirino_20.jpg
#   inflating: /home/ubuntu/data/test/Chris_Cirino_21.jpg
#   inflating: /home/ubuntu/data/test/Chris_Cirino_30.jpg
#   inflating: /home/ubuntu/data/test/Chris_Cirino_31.jpg
#   inflating: /home/ubuntu/data/test/Chris_Cirino_50.jpg
#   inflating: /home/ubuntu/data/test/Chris_Cirino_51.jpg
#   inflating: /home/ubuntu/data/test/Chris_Cooper_00.jpg
#   inflating: /home/ubuntu/data/test/Chris_Cooper_01.jpg
#   inflating: /home/ubuntu/data/test/Chris_Cooper_30.jpg
#   inflating: /home/ubuntu/data/test/Chris_Cooper_31.jpg
#   inflating: /home/ubuntu/data/test/Chris_Cooper_40.jpg
#   inflating: /home/ubuntu/data/test/Chris_Cooper_41.jpg
#   inflating: /home/ubuntu/data/test/Chris_Matthews_00.jpg
#   inflating: /home/ubuntu/data/test/Chris_Matthews_01.jpg
#   inflating: /home/ubuntu/data/test/Chris_Matthews_10.jpg
#   inflating: /home/ubuntu/data/test/Chris_Matthews_11.jpg
#   inflating: /home/ubuntu/data/test/Chris_Matthews_30.jpg
#   inflating: /home/ubuntu/data/test/Chris_Matthews_31.jpg
#   inflating: /home/ubuntu/data/test/Chris_Matthews_50.jpg
#   inflating: /home/ubuntu/data/test/Chris_Matthews_51.jpg
#   inflating: /home/ubuntu/data/test/Chris_Noth_00.jpg
#   inflating: /home/ubuntu/data/test/Chris_Noth_01.jpg
#   inflating: /home/ubuntu/data/test/Chris_Noth_10.jpg
#   inflating: /home/ubuntu/data/test/Chris_Noth_11.jpg
#   inflating: /home/ubuntu/data/test/Chris_Noth_30.jpg
#   inflating: /home/ubuntu/data/test/Chris_Noth_31.jpg
#   inflating: /home/ubuntu/data/test/Chris_Rock_00.jpg
#   inflating: /home/ubuntu/data/test/Chris_Rock_01.jpg
#   inflating: /home/ubuntu/data/test/Chris_Rock_10.jpg
#   inflating: /home/ubuntu/data/test/Chris_Rock_11.jpg
#   inflating: /home/ubuntu/data/test/Chris_Rock_20.jpg
#   inflating: /home/ubuntu/data/test/Chris_Rock_21.jpg
#   inflating: /home/ubuntu/data/test/Christine_Ebersole_00.jpg
#   inflating: /home/ubuntu/data/test/Christine_Ebersole_01.jpg
#   inflating: /home/ubuntu/data/test/Christine_Ebersole_20.jpg
#   inflating: /home/ubuntu/data/test/Christine_Ebersole_21.jpg
#   inflating: /home/ubuntu/data/test/Christine_Ebersole_50.jpg
#   inflating: /home/ubuntu/data/test/Christine_Ebersole_51.jpg
#   inflating: /home/ubuntu/data/test/Christopher_Amolsch_20.jpg
#   inflating: /home/ubuntu/data/test/Christopher_Amolsch_21.jpg
#   inflating: /home/ubuntu/data/test/Christopher_Amolsch_40.jpg
#   inflating: /home/ubuntu/data/test/Christopher_Amolsch_41.jpg
#   inflating: /home/ubuntu/data/test/Christopher_Amolsch_50.jpg
#   inflating: /home/ubuntu/data/test/Christopher_Amolsch_51.jpg
#   inflating: /home/ubuntu/data/test/Christopher_Reeve_10.jpg
#   inflating: /home/ubuntu/data/test/Christopher_Reeve_11.jpg
#   inflating: /home/ubuntu/data/test/Christopher_Reeve_20.jpg
#   inflating: /home/ubuntu/data/test/Christopher_Reeve_21.jpg
#   inflating: /home/ubuntu/data/test/Christopher_Reeve_40.jpg
#   inflating: /home/ubuntu/data/test/Christopher_Reeve_41.jpg
#   inflating: /home/ubuntu/data/test/Christopher_Walken_00.jpg
#   inflating: /home/ubuntu/data/test/Christopher_Walken_01.jpg
#   inflating: /home/ubuntu/data/test/Christopher_Walken_20.jpg
#   inflating: /home/ubuntu/data/test/Christopher_Walken_21.jpg
#   inflating: /home/ubuntu/data/test/Christopher_Walken_40.jpg
#   inflating: /home/ubuntu/data/test/Christopher_Walken_41.jpg
#   inflating: /home/ubuntu/data/test/Christopher_Walken_50.jpg
#   inflating: /home/ubuntu/data/test/Christopher_Walken_51.jpg
#   inflating: /home/ubuntu/data/test/Chuck_Hagel_20.jpg
#   inflating: /home/ubuntu/data/test/Chuck_Hagel_21.jpg
#   inflating: /home/ubuntu/data/test/Chuck_Hagel_30.jpg
#   inflating: /home/ubuntu/data/test/Chuck_Hagel_31.jpg
#   inflating: /home/ubuntu/data/test/Chuck_Hagel_40.jpg
#   inflating: /home/ubuntu/data/test/Chuck_Hagel_41.jpg
#   inflating: /home/ubuntu/data/test/Chuck_Hagel_50.jpg
#   inflating: /home/ubuntu/data/test/Chuck_Hagel_51.jpg
#   inflating: /home/ubuntu/data/test/Chuck_Woolery_10.jpg
#   inflating: /home/ubuntu/data/test/Chuck_Woolery_11.jpg
#   inflating: /home/ubuntu/data/test/Chuck_Woolery_20.jpg
#   inflating: /home/ubuntu/data/test/Chuck_Woolery_21.jpg
#   inflating: /home/ubuntu/data/test/Chuck_Woolery_40.jpg
#   inflating: /home/ubuntu/data/test/Chuck_Woolery_41.jpg
#   inflating: /home/ubuntu/data/test/Cindy_Crawford_00.jpg
#   inflating: /home/ubuntu/data/test/Cindy_Crawford_01.jpg
#   inflating: /home/ubuntu/data/test/Cindy_Crawford_30.jpg
#   inflating: /home/ubuntu/data/test/Cindy_Crawford_31.jpg
#   inflating: /home/ubuntu/data/test/Cindy_Crawford_50.jpg
#   inflating: /home/ubuntu/data/test/Cindy_Crawford_51.jpg
#   inflating: /home/ubuntu/data/test/Cindy_Klassen_00.jpg
#   inflating: /home/ubuntu/data/test/Cindy_Klassen_01.jpg
#   inflating: /home/ubuntu/data/test/Cindy_Klassen_30.jpg
#   inflating: /home/ubuntu/data/test/Cindy_Klassen_31.jpg
#   inflating: /home/ubuntu/data/test/Cindy_Klassen_40.jpg
#   inflating: /home/ubuntu/data/test/Cindy_Klassen_41.jpg
#   inflating: /home/ubuntu/data/test/Claire_Danes_30.jpg
#   inflating: /home/ubuntu/data/test/Claire_Danes_31.jpg
#   inflating: /home/ubuntu/data/test/Claire_Danes_40.jpg
#   inflating: /home/ubuntu/data/test/Claire_Danes_41.jpg
#   inflating: /home/ubuntu/data/test/Claire_Danes_50.jpg
#   inflating: /home/ubuntu/data/test/Claire_Danes_51.jpg
#   inflating: /home/ubuntu/data/test/Clark_Randt_10.jpg
#   inflating: /home/ubuntu/data/test/Clark_Randt_11.jpg
#   inflating: /home/ubuntu/data/test/Clark_Randt_20.jpg
#   inflating: /home/ubuntu/data/test/Clark_Randt_21.jpg
#   inflating: /home/ubuntu/data/test/Clark_Randt_40.jpg
#   inflating: /home/ubuntu/data/test/Clark_Randt_41.jpg
#   inflating: /home/ubuntu/data/test/Clark_Randt_50.jpg
#   inflating: /home/ubuntu/data/test/Clark_Randt_51.jpg
#   inflating: /home/ubuntu/data/test/Clay_Aiken_00.jpg
#   inflating: /home/ubuntu/data/test/Clay_Aiken_01.jpg
#   inflating: /home/ubuntu/data/test/Clay_Aiken_30.jpg
#   inflating: /home/ubuntu/data/test/Clay_Aiken_31.jpg
#   inflating: /home/ubuntu/data/test/Clay_Aiken_40.jpg
#   inflating: /home/ubuntu/data/test/Clay_Aiken_41.jpg
#   inflating: /home/ubuntu/data/test/Clay_Aiken_50.jpg
#   inflating: /home/ubuntu/data/test/Clay_Aiken_51.jpg
#   inflating: /home/ubuntu/data/test/Clint_Howard_00.jpg
#   inflating: /home/ubuntu/data/test/Clint_Howard_01.jpg
#   inflating: /home/ubuntu/data/test/Clint_Howard_10.jpg
#   inflating: /home/ubuntu/data/test/Clint_Howard_11.jpg
#   inflating: /home/ubuntu/data/test/Clint_Howard_20.jpg
#   inflating: /home/ubuntu/data/test/Clint_Howard_21.jpg
#   inflating: /home/ubuntu/data/test/Clint_Howard_30.jpg
#   inflating: /home/ubuntu/data/test/Clint_Howard_31.jpg
#   inflating: /home/ubuntu/data/test/Clive_Lloyd_30.jpg
#   inflating: /home/ubuntu/data/test/Clive_Lloyd_31.jpg
#   inflating: /home/ubuntu/data/test/Clive_Lloyd_40.jpg
#   inflating: /home/ubuntu/data/test/Clive_Lloyd_41.jpg
#   inflating: /home/ubuntu/data/test/Clive_Lloyd_50.jpg
#   inflating: /home/ubuntu/data/test/Clive_Lloyd_51.jpg
#   inflating: /home/ubuntu/data/test/Colin_Powell_10.jpg
#   inflating: /home/ubuntu/data/test/Colin_Powell_11.jpg
#   inflating: /home/ubuntu/data/test/Colin_Powell_40.jpg
#   inflating: /home/ubuntu/data/test/Colin_Powell_41.jpg
#   inflating: /home/ubuntu/data/test/Colin_Powell_50.jpg
#   inflating: /home/ubuntu/data/test/Colin_Powell_51.jpg
#   inflating: /home/ubuntu/data/test/Conan_OBrien_00.jpg
#   inflating: /home/ubuntu/data/test/Conan_OBrien_01.jpg
#   inflating: /home/ubuntu/data/test/Conan_OBrien_10.jpg
#   inflating: /home/ubuntu/data/test/Conan_OBrien_11.jpg
#   inflating: /home/ubuntu/data/test/Conan_OBrien_50.jpg
#   inflating: /home/ubuntu/data/test/Conan_OBrien_51.jpg
#   inflating: /home/ubuntu/data/test/Condoleezza_Rice_10.jpg
#   inflating: /home/ubuntu/data/test/Condoleezza_Rice_11.jpg
#   inflating: /home/ubuntu/data/test/Condoleezza_Rice_20.jpg
#   inflating: /home/ubuntu/data/test/Condoleezza_Rice_21.jpg
#   inflating: /home/ubuntu/data/test/Condoleezza_Rice_30.jpg
#   inflating: /home/ubuntu/data/test/Condoleezza_Rice_31.jpg
#   inflating: /home/ubuntu/data/test/Condoleezza_Rice_40.jpg
#   inflating: /home/ubuntu/data/test/Condoleezza_Rice_41.jpg
#   inflating: /home/ubuntu/data/test/Connie_Chung_20.jpg
#   inflating: /home/ubuntu/data/test/Connie_Chung_21.jpg
#   inflating: /home/ubuntu/data/test/Connie_Chung_30.jpg
#   inflating: /home/ubuntu/data/test/Connie_Chung_31.jpg
#   inflating: /home/ubuntu/data/test/Connie_Chung_40.jpg
#   inflating: /home/ubuntu/data/test/Connie_Chung_41.jpg
#   inflating: /home/ubuntu/data/test/Connie_Chung_50.jpg
#   inflating: /home/ubuntu/data/test/Connie_Chung_51.jpg
#   inflating: /home/ubuntu/data/test/Craig_David_10.jpg
#   inflating: /home/ubuntu/data/test/Craig_David_11.jpg
#   inflating: /home/ubuntu/data/test/Craig_David_20.jpg
#   inflating: /home/ubuntu/data/test/Craig_David_21.jpg
#   inflating: /home/ubuntu/data/test/Craig_David_30.jpg
#   inflating: /home/ubuntu/data/test/Craig_David_31.jpg
#   inflating: /home/ubuntu/data/test/Craig_David_50.jpg
#   inflating: /home/ubuntu/data/test/Craig_David_51.jpg
#   inflating: /home/ubuntu/data/test/Cristina_Fernandez_30.jpg
#   inflating: /home/ubuntu/data/test/Cristina_Fernandez_31.jpg
#   inflating: /home/ubuntu/data/test/Cristina_Fernandez_40.jpg
#   inflating: /home/ubuntu/data/test/Cristina_Fernandez_41.jpg
#   inflating: /home/ubuntu/data/test/Cristina_Fernandez_50.jpg
#   inflating: /home/ubuntu/data/test/Cristina_Fernandez_51.jpg
#   inflating: /home/ubuntu/data/test/Cristina_Saralegui_00.jpg
#   inflating: /home/ubuntu/data/test/Cristina_Saralegui_01.jpg
#   inflating: /home/ubuntu/data/test/Cristina_Saralegui_30.jpg
#   inflating: /home/ubuntu/data/test/Cristina_Saralegui_31.jpg
#   inflating: /home/ubuntu/data/test/Cristina_Saralegui_50.jpg
#   inflating: /home/ubuntu/data/test/Cristina_Saralegui_51.jpg
#   inflating: /home/ubuntu/data/test/Dai_Bachtiar_00.jpg
#   inflating: /home/ubuntu/data/test/Dai_Bachtiar_01.jpg
#   inflating: /home/ubuntu/data/test/Dai_Bachtiar_10.jpg
#   inflating: /home/ubuntu/data/test/Dai_Bachtiar_11.jpg
#   inflating: /home/ubuntu/data/test/Dai_Bachtiar_20.jpg
#   inflating: /home/ubuntu/data/test/Dai_Bachtiar_21.jpg
#   inflating: /home/ubuntu/data/test/Dai_Bachtiar_50.jpg
#   inflating: /home/ubuntu/data/test/Dai_Bachtiar_51.jpg
#   inflating: /home/ubuntu/data/test/Daisy_Fuentes_20.jpg
#   inflating: /home/ubuntu/data/test/Daisy_Fuentes_21.jpg
#   inflating: /home/ubuntu/data/test/Daisy_Fuentes_30.jpg
#   inflating: /home/ubuntu/data/test/Daisy_Fuentes_31.jpg
#   inflating: /home/ubuntu/data/test/Daisy_Fuentes_40.jpg
#   inflating: /home/ubuntu/data/test/Daisy_Fuentes_41.jpg
#   inflating: /home/ubuntu/data/test/Dan_Ackroyd_00.jpg
#   inflating: /home/ubuntu/data/test/Dan_Ackroyd_01.jpg
#   inflating: /home/ubuntu/data/test/Dan_Ackroyd_20.jpg
#   inflating: /home/ubuntu/data/test/Dan_Ackroyd_21.jpg
#   inflating: /home/ubuntu/data/test/Dan_Ackroyd_30.jpg
#   inflating: /home/ubuntu/data/test/Dan_Ackroyd_31.jpg
#   inflating: /home/ubuntu/data/test/Daniel_Radcliffe_00.jpg
#   inflating: /home/ubuntu/data/test/Daniel_Radcliffe_01.jpg
#   inflating: /home/ubuntu/data/test/Daniel_Radcliffe_20.jpg
#   inflating: /home/ubuntu/data/test/Daniel_Radcliffe_21.jpg
#   inflating: /home/ubuntu/data/test/Daniel_Radcliffe_50.jpg
#   inflating: /home/ubuntu/data/test/Daniel_Radcliffe_51.jpg
#   inflating: /home/ubuntu/data/test/Daniel_Rouse_00.jpg
#   inflating: /home/ubuntu/data/test/Daniel_Rouse_01.jpg
#   inflating: /home/ubuntu/data/test/Daniel_Rouse_10.jpg
#   inflating: /home/ubuntu/data/test/Daniel_Rouse_11.jpg
#   inflating: /home/ubuntu/data/test/Daniel_Rouse_20.jpg
#   inflating: /home/ubuntu/data/test/Daniel_Rouse_21.jpg
#   inflating: /home/ubuntu/data/test/Daniel_Rouse_30.jpg
#   inflating: /home/ubuntu/data/test/Daniel_Rouse_31.jpg
#   inflating: /home/ubuntu/data/test/Daniell_Sunjata_10.jpg
#   inflating: /home/ubuntu/data/test/Daniell_Sunjata_11.jpg
#   inflating: /home/ubuntu/data/test/Daniell_Sunjata_20.jpg
#   inflating: /home/ubuntu/data/test/Daniell_Sunjata_21.jpg
#   inflating: /home/ubuntu/data/test/Daniell_Sunjata_40.jpg
#   inflating: /home/ubuntu/data/test/Daniell_Sunjata_41.jpg
#   inflating: /home/ubuntu/data/test/Danny_Glover_10.jpg
#   inflating: /home/ubuntu/data/test/Danny_Glover_11.jpg
#   inflating: /home/ubuntu/data/test/Danny_Glover_30.jpg
#   inflating: /home/ubuntu/data/test/Danny_Glover_31.jpg
#   inflating: /home/ubuntu/data/test/Danny_Glover_50.jpg
#   inflating: /home/ubuntu/data/test/Danny_Glover_51.jpg
#   inflating: /home/ubuntu/data/test/Darrell_Issa_00.jpg
#   inflating: /home/ubuntu/data/test/Darrell_Issa_01.jpg
#   inflating: /home/ubuntu/data/test/Darrell_Issa_20.jpg
#   inflating: /home/ubuntu/data/test/Darrell_Issa_21.jpg
#   inflating: /home/ubuntu/data/test/Darrell_Issa_30.jpg
#   inflating: /home/ubuntu/data/test/Darrell_Issa_31.jpg
#   inflating: /home/ubuntu/data/test/Darrell_Issa_40.jpg
#   inflating: /home/ubuntu/data/test/Darrell_Issa_41.jpg
#   inflating: /home/ubuntu/data/test/Dave_Campo_10.jpg
#   inflating: /home/ubuntu/data/test/Dave_Campo_11.jpg
#   inflating: /home/ubuntu/data/test/Dave_Campo_20.jpg
#   inflating: /home/ubuntu/data/test/Dave_Campo_21.jpg
#   inflating: /home/ubuntu/data/test/Dave_Campo_30.jpg
#   inflating: /home/ubuntu/data/test/Dave_Campo_31.jpg
#   inflating: /home/ubuntu/data/test/David_Brent_00.jpg
#   inflating: /home/ubuntu/data/test/David_Brent_01.jpg
#   inflating: /home/ubuntu/data/test/David_Brent_10.jpg
#   inflating: /home/ubuntu/data/test/David_Brent_11.jpg
#   inflating: /home/ubuntu/data/test/David_Brent_20.jpg
#   inflating: /home/ubuntu/data/test/David_Brent_21.jpg
#   inflating: /home/ubuntu/data/test/David_Brent_30.jpg
#   inflating: /home/ubuntu/data/test/David_Brent_31.jpg
#   inflating: /home/ubuntu/data/test/David_Caruso_00.jpg
#   inflating: /home/ubuntu/data/test/David_Caruso_01.jpg
#   inflating: /home/ubuntu/data/test/David_Caruso_10.jpg
#   inflating: /home/ubuntu/data/test/David_Caruso_11.jpg
#   inflating: /home/ubuntu/data/test/David_Caruso_30.jpg
#   inflating: /home/ubuntu/data/test/David_Caruso_31.jpg
#   inflating: /home/ubuntu/data/test/David_Caruso_40.jpg
#   inflating: /home/ubuntu/data/test/David_Caruso_41.jpg
#   inflating: /home/ubuntu/data/test/Ed_Rendell_00.jpg
#   inflating: /home/ubuntu/data/test/Ed_Rendell_01.jpg
#   inflating: /home/ubuntu/data/test/Ed_Rendell_20.jpg
#   inflating: /home/ubuntu/data/test/Ed_Rendell_21.jpg
#   inflating: /home/ubuntu/data/test/Ed_Rendell_50.jpg
#   inflating: /home/ubuntu/data/test/Ed_Rendell_51.jpg
#   inflating: /home/ubuntu/data/test/Ed_Smart_10.jpg
#   inflating: /home/ubuntu/data/test/Ed_Smart_11.jpg
#   inflating: /home/ubuntu/data/test/Ed_Smart_30.jpg
#   inflating: /home/ubuntu/data/test/Ed_Smart_31.jpg
#   inflating: /home/ubuntu/data/test/Ed_Smart_50.jpg
#   inflating: /home/ubuntu/data/test/Ed_Smart_51.jpg
#   inflating: /home/ubuntu/data/test/Edie_Falco_20.jpg
#   inflating: /home/ubuntu/data/test/Edie_Falco_21.jpg
#   inflating: /home/ubuntu/data/test/Edie_Falco_30.jpg
#   inflating: /home/ubuntu/data/test/Edie_Falco_31.jpg
#   inflating: /home/ubuntu/data/test/Edie_Falco_40.jpg
#   inflating: /home/ubuntu/data/test/Edie_Falco_41.jpg
#   inflating: /home/ubuntu/data/test/Edie_Falco_50.jpg
#   inflating: /home/ubuntu/data/test/Edie_Falco_51.jpg
#   inflating: /home/ubuntu/data/test/Eduardo_Duhalde_00.jpg
#   inflating: /home/ubuntu/data/test/Eduardo_Duhalde_01.jpg
#   inflating: /home/ubuntu/data/test/Eduardo_Duhalde_10.jpg
#   inflating: /home/ubuntu/data/test/Eduardo_Duhalde_11.jpg
#   inflating: /home/ubuntu/data/test/Eduardo_Duhalde_30.jpg
#   inflating: /home/ubuntu/data/test/Eduardo_Duhalde_31.jpg
#   inflating: /home/ubuntu/data/test/Edward_Burns_10.jpg
#   inflating: /home/ubuntu/data/test/Edward_Burns_11.jpg
#   inflating: /home/ubuntu/data/test/Edward_Burns_20.jpg
#   inflating: /home/ubuntu/data/test/Edward_Burns_21.jpg
#   inflating: /home/ubuntu/data/test/Edward_Burns_30.jpg
#   inflating: /home/ubuntu/data/test/Edward_Burns_31.jpg
#   inflating: /home/ubuntu/data/test/Edward_Burns_50.jpg
#   inflating: /home/ubuntu/data/test/Edward_Burns_51.jpg
#   inflating: /home/ubuntu/data/test/Edward_Norton_10.jpg
#   inflating: /home/ubuntu/data/test/Edward_Norton_11.jpg
#   inflating: /home/ubuntu/data/test/Edward_Norton_30.jpg
#   inflating: /home/ubuntu/data/test/Edward_Norton_31.jpg
#   inflating: /home/ubuntu/data/test/Edward_Norton_40.jpg
#   inflating: /home/ubuntu/data/test/Edward_Norton_41.jpg
#   inflating: /home/ubuntu/data/test/Edward_Norton_50.jpg
#   inflating: /home/ubuntu/data/test/Edward_Norton_51.jpg
#   inflating: /home/ubuntu/data/test/Elaine_Chao_00.jpg
#   inflating: /home/ubuntu/data/test/Elaine_Chao_01.jpg
#   inflating: /home/ubuntu/data/test/Elaine_Chao_20.jpg
#   inflating: /home/ubuntu/data/test/Elaine_Chao_21.jpg
#   inflating: /home/ubuntu/data/test/Elaine_Chao_50.jpg
#   inflating: /home/ubuntu/data/test/Elaine_Chao_51.jpg
#   inflating: /home/ubuntu/data/test/Elaine_Stritch_10.jpg
#   inflating: /home/ubuntu/data/test/Elaine_Stritch_11.jpg
#   inflating: /home/ubuntu/data/test/Elaine_Stritch_40.jpg
#   inflating: /home/ubuntu/data/test/Elaine_Stritch_41.jpg
#   inflating: /home/ubuntu/data/test/Elaine_Stritch_50.jpg
#   inflating: /home/ubuntu/data/test/Elaine_Stritch_51.jpg
#   inflating: /home/ubuntu/data/test/Eliane_Karp_00.jpg
#   inflating: /home/ubuntu/data/test/Eliane_Karp_01.jpg
#   inflating: /home/ubuntu/data/test/Eliane_Karp_10.jpg
#   inflating: /home/ubuntu/data/test/Eliane_Karp_11.jpg
#   inflating: /home/ubuntu/data/test/Eliane_Karp_30.jpg
#   inflating: /home/ubuntu/data/test/Eliane_Karp_31.jpg
#   inflating: /home/ubuntu/data/test/Eliane_Karp_40.jpg
#   inflating: /home/ubuntu/data/test/Eliane_Karp_41.jpg
#   inflating: /home/ubuntu/data/test/Elijah_Wood_00.jpg
#   inflating: /home/ubuntu/data/test/Elijah_Wood_01.jpg
#   inflating: /home/ubuntu/data/test/Elijah_Wood_10.jpg
#   inflating: /home/ubuntu/data/test/Elijah_Wood_11.jpg
#   inflating: /home/ubuntu/data/test/Elijah_Wood_30.jpg
#   inflating: /home/ubuntu/data/test/Elijah_Wood_31.jpg
#   inflating: /home/ubuntu/data/test/Eliza_Dushku_00.jpg
#   inflating: /home/ubuntu/data/test/Eliza_Dushku_01.jpg
#   inflating: /home/ubuntu/data/test/Eliza_Dushku_10.jpg
#   inflating: /home/ubuntu/data/test/Eliza_Dushku_11.jpg
#   inflating: /home/ubuntu/data/test/Eliza_Dushku_20.jpg
#   inflating: /home/ubuntu/data/test/Eliza_Dushku_21.jpg
#   inflating: /home/ubuntu/data/test/Eliza_Dushku_30.jpg
#   inflating: /home/ubuntu/data/test/Eliza_Dushku_31.jpg
#   inflating: /home/ubuntu/data/test/Elizabeth_Dole_00.jpg
#   inflating: /home/ubuntu/data/test/Elizabeth_Dole_01.jpg
#   inflating: /home/ubuntu/data/test/Elizabeth_Dole_10.jpg
#   inflating: /home/ubuntu/data/test/Elizabeth_Dole_11.jpg
#   inflating: /home/ubuntu/data/test/Elizabeth_Dole_30.jpg
#   inflating: /home/ubuntu/data/test/Elizabeth_Dole_31.jpg
#   inflating: /home/ubuntu/data/test/Elizabeth_Shue_00.jpg
#   inflating: /home/ubuntu/data/test/Elizabeth_Shue_01.jpg
#   inflating: /home/ubuntu/data/test/Elizabeth_Shue_20.jpg
#   inflating: /home/ubuntu/data/test/Elizabeth_Shue_21.jpg
#   inflating: /home/ubuntu/data/test/Elizabeth_Shue_40.jpg
#   inflating: /home/ubuntu/data/test/Elizabeth_Shue_41.jpg
#   inflating: /home/ubuntu/data/test/Ellen_DeGeneres_10.jpg
#   inflating: /home/ubuntu/data/test/Ellen_DeGeneres_11.jpg
#   inflating: /home/ubuntu/data/test/Ellen_DeGeneres_40.jpg
#   inflating: /home/ubuntu/data/test/Ellen_DeGeneres_41.jpg
#   inflating: /home/ubuntu/data/test/Ellen_DeGeneres_50.jpg
#   inflating: /home/ubuntu/data/test/Ellen_DeGeneres_51.jpg
#   inflating: /home/ubuntu/data/test/Elmar_Brok_00.jpg
#   inflating: /home/ubuntu/data/test/Elmar_Brok_01.jpg
#   inflating: /home/ubuntu/data/test/Elmar_Brok_20.jpg
#   inflating: /home/ubuntu/data/test/Elmar_Brok_21.jpg
#   inflating: /home/ubuntu/data/test/Elmar_Brok_30.jpg
#   inflating: /home/ubuntu/data/test/Elmar_Brok_31.jpg
#   inflating: /home/ubuntu/data/test/Elsa_Zylberstein_00.jpg
#   inflating: /home/ubuntu/data/test/Elsa_Zylberstein_01.jpg
#   inflating: /home/ubuntu/data/test/Elsa_Zylberstein_10.jpg
#   inflating: /home/ubuntu/data/test/Elsa_Zylberstein_11.jpg
#   inflating: /home/ubuntu/data/test/Elsa_Zylberstein_40.jpg
#   inflating: /home/ubuntu/data/test/Elsa_Zylberstein_41.jpg
#   inflating: /home/ubuntu/data/test/Elton_John_10.jpg
#   inflating: /home/ubuntu/data/test/Elton_John_11.jpg
#   inflating: /home/ubuntu/data/test/Elton_John_20.jpg
#   inflating: /home/ubuntu/data/test/Elton_John_21.jpg
#   inflating: /home/ubuntu/data/test/Elton_John_30.jpg
#   inflating: /home/ubuntu/data/test/Elton_John_31.jpg
#   inflating: /home/ubuntu/data/test/Elton_John_40.jpg
#   inflating: /home/ubuntu/data/test/Elton_John_41.jpg
#   inflating: /home/ubuntu/data/test/Emile_Lahoud_00.jpg
#   inflating: /home/ubuntu/data/test/Emile_Lahoud_01.jpg
#   inflating: /home/ubuntu/data/test/Emile_Lahoud_30.jpg
#   inflating: /home/ubuntu/data/test/Emile_Lahoud_31.jpg
#   inflating: /home/ubuntu/data/test/Emile_Lahoud_40.jpg
# ...
#   inflating: /home/ubuntu/data/training/Timothy_Goebel_01.jpg
#   inflating: /home/ubuntu/data/training/Timothy_Goebel_02.jpg
#   inflating: /home/ubuntu/data/training/Timothy_Goebel_30.jpg
#   inflating: /home/ubuntu/data/training/Timothy_Goebel_31.jpg
#   inflating: /home/ubuntu/data/training/Timothy_Goebel_32.jpg
#   inflating: /home/ubuntu/data/training/Timothy_Goebel_40.jpg
#   inflating: /home/ubuntu/data/training/Timothy_Goebel_41.jpg
#   inflating: /home/ubuntu/data/training/Timothy_Goebel_42.jpg
#   inflating: /home/ubuntu/data/training/Timothy_Goebel_50.jpg
#   inflating: /home/ubuntu/data/training/Timothy_Goebel_51.jpg
#   inflating: /home/ubuntu/data/training/Timothy_Goebel_52.jpg
#   inflating: /home/ubuntu/data/training/Tina_Brown_20.jpg
#   inflating: /home/ubuntu/data/training/Tina_Brown_21.jpg
#   inflating: /home/ubuntu/data/training/Tina_Brown_22.jpg
#   inflating: /home/ubuntu/data/training/Tina_Brown_40.jpg
#   inflating: /home/ubuntu/data/training/Tina_Brown_41.jpg
#   inflating: /home/ubuntu/data/training/Tina_Brown_42.jpg
#   inflating: /home/ubuntu/data/training/Tina_Brown_50.jpg
#   inflating: /home/ubuntu/data/training/Tina_Brown_51.jpg
#   inflating: /home/ubuntu/data/training/Tina_Brown_52.jpg
#   inflating: /home/ubuntu/data/training/Tom_Coughlin_20.jpg
#   inflating: /home/ubuntu/data/training/Tom_Coughlin_21.jpg
#   inflating: /home/ubuntu/data/training/Tom_Coughlin_22.jpg
#   inflating: /home/ubuntu/data/training/Tom_Coughlin_30.jpg
#   inflating: /home/ubuntu/data/training/Tom_Coughlin_31.jpg
#   inflating: /home/ubuntu/data/training/Tom_Coughlin_32.jpg
#   inflating: /home/ubuntu/data/training/Tom_Coughlin_50.jpg
#   inflating: /home/ubuntu/data/training/Tom_Coughlin_51.jpg
#   inflating: /home/ubuntu/data/training/Tom_Coughlin_52.jpg
#   inflating: /home/ubuntu/data/training/Tom_Hanks_30.jpg
#   inflating: /home/ubuntu/data/training/Tom_Hanks_31.jpg
#   inflating: /home/ubuntu/data/training/Tom_Hanks_32.jpg
#   inflating: /home/ubuntu/data/training/Tom_Hanks_40.jpg
#   inflating: /home/ubuntu/data/training/Tom_Hanks_41.jpg
#   inflating: /home/ubuntu/data/training/Tom_Hanks_42.jpg
#   inflating: /home/ubuntu/data/training/Tom_Hanks_50.jpg
#   inflating: /home/ubuntu/data/training/Tom_Hanks_51.jpg
#   inflating: /home/ubuntu/data/training/Tom_Hanks_52.jpg
#   inflating: /home/ubuntu/data/training/Tom_Harkin_00.jpg
#   inflating: /home/ubuntu/data/training/Tom_Harkin_01.jpg
#   inflating: /home/ubuntu/data/training/Tom_Harkin_02.jpg
#   inflating: /home/ubuntu/data/training/Tom_Harkin_30.jpg
#   inflating: /home/ubuntu/data/training/Tom_Harkin_31.jpg
#   inflating: /home/ubuntu/data/training/Tom_Harkin_32.jpg
#   inflating: /home/ubuntu/data/training/Tom_Harkin_40.jpg
#   inflating: /home/ubuntu/data/training/Tom_Harkin_41.jpg
#   inflating: /home/ubuntu/data/training/Tom_Harkin_42.jpg
#   inflating: /home/ubuntu/data/training/Tom_Osborne_20.jpg
#   inflating: /home/ubuntu/data/training/Tom_Osborne_21.jpg
#   inflating: /home/ubuntu/data/training/Tom_Osborne_22.jpg
#   inflating: /home/ubuntu/data/training/Tom_Osborne_30.jpg
#   inflating: /home/ubuntu/data/training/Tom_Osborne_31.jpg
#   inflating: /home/ubuntu/data/training/Tom_Osborne_32.jpg
#   inflating: /home/ubuntu/data/training/Tom_Osborne_50.jpg
#   inflating: /home/ubuntu/data/training/Tom_Osborne_51.jpg
#   inflating: /home/ubuntu/data/training/Tom_Osborne_52.jpg
#   inflating: /home/ubuntu/data/training/Tom_Ridge_20.jpg
#   inflating: /home/ubuntu/data/training/Tom_Ridge_21.jpg
#   inflating: /home/ubuntu/data/training/Tom_Ridge_22.jpg
#   inflating: /home/ubuntu/data/training/Tom_Ridge_30.jpg
#   inflating: /home/ubuntu/data/training/Tom_Ridge_31.jpg
#   inflating: /home/ubuntu/data/training/Tom_Ridge_32.jpg
#   inflating: /home/ubuntu/data/training/Tom_Ridge_50.jpg
#   inflating: /home/ubuntu/data/training/Tom_Ridge_51.jpg
#   inflating: /home/ubuntu/data/training/Tom_Ridge_52.jpg
#   inflating: /home/ubuntu/data/training/Tom_Sizemore_00.jpg
#   inflating: /home/ubuntu/data/training/Tom_Sizemore_01.jpg
#   inflating: /home/ubuntu/data/training/Tom_Sizemore_02.jpg
#   inflating: /home/ubuntu/data/training/Tom_Sizemore_10.jpg
#   inflating: /home/ubuntu/data/training/Tom_Sizemore_11.jpg
#   inflating: /home/ubuntu/data/training/Tom_Sizemore_12.jpg
#   inflating: /home/ubuntu/data/training/Tom_Sizemore_20.jpg
#   inflating: /home/ubuntu/data/training/Tom_Sizemore_21.jpg
#   inflating: /home/ubuntu/data/training/Tom_Sizemore_22.jpg
#   inflating: /home/ubuntu/data/training/Valerie_Harper_00.jpg
#   inflating: /home/ubuntu/data/training/Valerie_Harper_01.jpg
#   inflating: /home/ubuntu/data/training/Valerie_Harper_02.jpg
#   inflating: /home/ubuntu/data/training/Valerie_Harper_30.jpg
#   inflating: /home/ubuntu/data/training/Valerie_Harper_31.jpg
#   inflating: /home/ubuntu/data/training/Valerie_Harper_32.jpg
#   inflating: /home/ubuntu/data/training/Valerie_Harper_40.jpg
#   inflating: /home/ubuntu/data/training/Valerie_Harper_41.jpg
#   inflating: /home/ubuntu/data/training/Valerie_Harper_42.jpg
#   inflating: /home/ubuntu/data/training/Valerie_Harper_50.jpg
#   inflating: /home/ubuntu/data/training/Valerie_Harper_51.jpg
#   inflating: /home/ubuntu/data/training/Valerie_Harper_52.jpg
#   inflating: /home/ubuntu/data/training/Vicente_Fox_10.jpg
#   inflating: /home/ubuntu/data/training/Vicente_Fox_11.jpg
#   inflating: /home/ubuntu/data/training/Vicente_Fox_12.jpg
#   inflating: /home/ubuntu/data/training/Vicente_Fox_20.jpg
#   inflating: /home/ubuntu/data/training/Vicente_Fox_21.jpg
#   inflating: /home/ubuntu/data/training/Vicente_Fox_22.jpg
#   inflating: /home/ubuntu/data/training/Vicente_Fox_30.jpg
#   inflating: /home/ubuntu/data/training/Vicente_Fox_31.jpg
#   inflating: /home/ubuntu/data/training/Vicente_Fox_32.jpg
#   inflating: /home/ubuntu/data/training/Vojislav_Seselj_00.jpg
#   inflating: /home/ubuntu/data/training/Vojislav_Seselj_01.jpg
#   inflating: /home/ubuntu/data/training/Vojislav_Seselj_02.jpg
#   inflating: /home/ubuntu/data/training/Vojislav_Seselj_20.jpg
#   inflating: /home/ubuntu/data/training/Vojislav_Seselj_21.jpg
#   inflating: /home/ubuntu/data/training/Vojislav_Seselj_22.jpg
#   inflating: /home/ubuntu/data/training/Vojislav_Seselj_40.jpg
#   inflating: /home/ubuntu/data/training/Vojislav_Seselj_41.jpg
#   inflating: /home/ubuntu/data/training/Vojislav_Seselj_42.jpg
#   inflating: /home/ubuntu/data/training/Vojislav_Seselj_50.jpg
#   inflating: /home/ubuntu/data/training/Vojislav_Seselj_51.jpg
#   inflating: /home/ubuntu/data/training/Vojislav_Seselj_52.jpg
#   inflating: /home/ubuntu/data/training/Warren_Beatty_10.jpg
#   inflating: /home/ubuntu/data/training/Warren_Beatty_11.jpg
#   inflating: /home/ubuntu/data/training/Warren_Beatty_12.jpg
#   inflating: /home/ubuntu/data/training/Warren_Beatty_30.jpg
#   inflating: /home/ubuntu/data/training/Warren_Beatty_31.jpg
#   inflating: /home/ubuntu/data/training/Warren_Beatty_32.jpg
#   inflating: /home/ubuntu/data/training/Warren_Beatty_50.jpg
#   inflating: /home/ubuntu/data/training/Warren_Beatty_51.jpg
#   inflating: /home/ubuntu/data/training/Warren_Beatty_52.jpg
#   inflating: /home/ubuntu/data/training/Warren_Buffett_00.jpg
#   inflating: /home/ubuntu/data/training/Warren_Buffett_01.jpg
#   inflating: /home/ubuntu/data/training/Warren_Buffett_02.jpg
#   inflating: /home/ubuntu/data/training/Warren_Buffett_30.jpg
#   inflating: /home/ubuntu/data/training/Warren_Buffett_31.jpg
#   inflating: /home/ubuntu/data/training/Warren_Buffett_32.jpg
#   inflating: /home/ubuntu/data/training/Warren_Buffett_40.jpg
#   inflating: /home/ubuntu/data/training/Warren_Buffett_41.jpg
#   inflating: /home/ubuntu/data/training/Warren_Buffett_42.jpg
#   inflating: /home/ubuntu/data/training/Warren_Buffett_50.jpg
#   inflating: /home/ubuntu/data/training/Warren_Buffett_51.jpg
#   inflating: /home/ubuntu/data/training/Warren_Buffett_52.jpg
#   inflating: /home/ubuntu/data/training/Wayne_Allard_00.jpg
#   inflating: /home/ubuntu/data/training/Wayne_Allard_01.jpg
#   inflating: /home/ubuntu/data/training/Wayne_Allard_02.jpg
#   inflating: /home/ubuntu/data/training/Wayne_Allard_20.jpg
#   inflating: /home/ubuntu/data/training/Wayne_Allard_21.jpg
#   inflating: /home/ubuntu/data/training/Wayne_Allard_22.jpg
#   inflating: /home/ubuntu/data/training/Wayne_Allard_50.jpg
#   inflating: /home/ubuntu/data/training/Wayne_Allard_51.jpg
#   inflating: /home/ubuntu/data/training/Wayne_Allard_52.jpg
#   inflating: /home/ubuntu/data/training/Wayne_Gretzky_20.jpg
#   inflating: /home/ubuntu/data/training/Wayne_Gretzky_21.jpg
#   inflating: /home/ubuntu/data/training/Wayne_Gretzky_22.jpg
#   inflating: /home/ubuntu/data/training/Wayne_Gretzky_30.jpg
#   inflating: /home/ubuntu/data/training/Wayne_Gretzky_31.jpg
#   inflating: /home/ubuntu/data/training/Wayne_Gretzky_32.jpg
#   inflating: /home/ubuntu/data/training/Wayne_Gretzky_40.jpg
#   inflating: /home/ubuntu/data/training/Wayne_Gretzky_41.jpg
#   inflating: /home/ubuntu/data/training/Wayne_Gretzky_42.jpg
#   inflating: /home/ubuntu/data/training/Wayne_Newton_10.jpg
#   inflating: /home/ubuntu/data/training/Wayne_Newton_11.jpg
#   inflating: /home/ubuntu/data/training/Wayne_Newton_12.jpg
#   inflating: /home/ubuntu/data/training/Wayne_Newton_20.jpg
#   inflating: /home/ubuntu/data/training/Wayne_Newton_21.jpg
#   inflating: /home/ubuntu/data/training/Wayne_Newton_22.jpg
#   inflating: /home/ubuntu/data/training/Wayne_Newton_40.jpg
#   inflating: /home/ubuntu/data/training/Wayne_Newton_41.jpg
#   inflating: /home/ubuntu/data/training/Wayne_Newton_42.jpg
#   inflating: /home/ubuntu/data/training/Wes_Craven_00.jpg
#   inflating: /home/ubuntu/data/training/Wes_Craven_01.jpg
#   inflating: /home/ubuntu/data/training/Wes_Craven_02.jpg
#   inflating: /home/ubuntu/data/training/Wes_Craven_20.jpg
#   inflating: /home/ubuntu/data/training/Wes_Craven_21.jpg
#   inflating: /home/ubuntu/data/training/Wes_Craven_22.jpg
#   inflating: /home/ubuntu/data/training/Wes_Craven_30.jpg
#   inflating: /home/ubuntu/data/training/Wes_Craven_31.jpg
#   inflating: /home/ubuntu/data/training/Wes_Craven_32.jpg
#   inflating: /home/ubuntu/data/training/Wes_Craven_50.jpg
#   inflating: /home/ubuntu/data/training/Wes_Craven_51.jpg
#   inflating: /home/ubuntu/data/training/Wes_Craven_52.jpg
#   inflating: /home/ubuntu/data/training/Wesley_Clark_00.jpg
#   inflating: /home/ubuntu/data/training/Wesley_Clark_01.jpg
#   inflating: /home/ubuntu/data/training/Wesley_Clark_02.jpg
#   inflating: /home/ubuntu/data/training/Wesley_Clark_20.jpg
#   inflating: /home/ubuntu/data/training/Wesley_Clark_21.jpg
#   inflating: /home/ubuntu/data/training/Wesley_Clark_22.jpg
#   inflating: /home/ubuntu/data/training/Wesley_Clark_30.jpg
#   inflating: /home/ubuntu/data/training/Wesley_Clark_31.jpg
#   inflating: /home/ubuntu/data/training/Wesley_Clark_32.jpg
#   inflating: /home/ubuntu/data/training/Wesley_Clark_40.jpg
#   inflating: /home/ubuntu/data/training/Wesley_Clark_41.jpg
#   inflating: /home/ubuntu/data/training/Wesley_Clark_42.jpg
#   inflating: /home/ubuntu/data/training/Whoopi_Goldberg_00.jpg
#   inflating: /home/ubuntu/data/training/Whoopi_Goldberg_01.jpg
#   inflating: /home/ubuntu/data/training/Whoopi_Goldberg_02.jpg
#   inflating: /home/ubuntu/data/training/Whoopi_Goldberg_40.jpg
#   inflating: /home/ubuntu/data/training/Whoopi_Goldberg_41.jpg
#   inflating: /home/ubuntu/data/training/Whoopi_Goldberg_42.jpg
#   inflating: /home/ubuntu/data/training/Whoopi_Goldberg_50.jpg
#   inflating: /home/ubuntu/data/training/Whoopi_Goldberg_51.jpg
#   inflating: /home/ubuntu/data/training/Whoopi_Goldberg_52.jpg
#   inflating: /home/ubuntu/data/training/William_Delahunt_00.jpg
#   inflating: /home/ubuntu/data/training/William_Delahunt_01.jpg
#   inflating: /home/ubuntu/data/training/William_Delahunt_02.jpg
#   inflating: /home/ubuntu/data/training/William_Delahunt_10.jpg
#   inflating: /home/ubuntu/data/training/William_Delahunt_11.jpg
#   inflating: /home/ubuntu/data/training/William_Delahunt_12.jpg
#   inflating: /home/ubuntu/data/training/William_Delahunt_20.jpg
#   inflating: /home/ubuntu/data/training/William_Delahunt_21.jpg
#   inflating: /home/ubuntu/data/training/William_Delahunt_22.jpg
#   inflating: /home/ubuntu/data/training/William_Donaldson_00.jpg
#   inflating: /home/ubuntu/data/training/William_Donaldson_01.jpg
#   inflating: /home/ubuntu/data/training/William_Donaldson_02.jpg
#   inflating: /home/ubuntu/data/training/William_Donaldson_10.jpg
#   inflating: /home/ubuntu/data/training/William_Donaldson_11.jpg
#   inflating: /home/ubuntu/data/training/William_Donaldson_12.jpg
#   inflating: /home/ubuntu/data/training/William_Donaldson_50.jpg
#   inflating: /home/ubuntu/data/training/William_Donaldson_51.jpg
#   inflating: /home/ubuntu/data/training/William_Donaldson_52.jpg
#   inflating: /home/ubuntu/data/training/William_McDonough_00.jpg
#   inflating: /home/ubuntu/data/training/William_McDonough_01.jpg
#   inflating: /home/ubuntu/data/training/William_McDonough_02.jpg
#   inflating: /home/ubuntu/data/training/William_McDonough_20.jpg
#   inflating: /home/ubuntu/data/training/William_McDonough_21.jpg
#   inflating: /home/ubuntu/data/training/William_McDonough_22.jpg
#   inflating: /home/ubuntu/data/training/William_McDonough_30.jpg
#   inflating: /home/ubuntu/data/training/William_McDonough_31.jpg
#   inflating: /home/ubuntu/data/training/William_McDonough_32.jpg
#   inflating: /home/ubuntu/data/training/William_McDonough_40.jpg
#   inflating: /home/ubuntu/data/training/William_McDonough_41.jpg
#   inflating: /home/ubuntu/data/training/William_McDonough_42.jpg
#   inflating: /home/ubuntu/data/training/Yang_Jianli_00.jpg
#   inflating: /home/ubuntu/data/training/Yang_Jianli_01.jpg
#   inflating: /home/ubuntu/data/training/Yang_Jianli_02.jpg
#   inflating: /home/ubuntu/data/training/Yang_Jianli_10.jpg
#   inflating: /home/ubuntu/data/training/Yang_Jianli_11.jpg
#   inflating: /home/ubuntu/data/training/Yang_Jianli_12.jpg
#   inflating: /home/ubuntu/data/training/Yang_Jianli_30.jpg
#   inflating: /home/ubuntu/data/training/Yang_Jianli_31.jpg
#   inflating: /home/ubuntu/data/training/Yang_Jianli_32.jpg
#   inflating: /home/ubuntu/data/training/Yuri_Fedotov_20.jpg
#   inflating: /home/ubuntu/data/training/Yuri_Fedotov_21.jpg
#   inflating: /home/ubuntu/data/training/Yuri_Fedotov_22.jpg
#   inflating: /home/ubuntu/data/training/Yuri_Fedotov_30.jpg
#   inflating: /home/ubuntu/data/training/Yuri_Fedotov_31.jpg
#   inflating: /home/ubuntu/data/training/Yuri_Fedotov_32.jpg
#   inflating: /home/ubuntu/data/training/Yuri_Fedotov_40.jpg
#   inflating: /home/ubuntu/data/training/Yuri_Fedotov_41.jpg
#   inflating: /home/ubuntu/data/training/Yuri_Fedotov_42.jpg
#   inflating: /home/ubuntu/data/training/Zhang_Ziyi_10.jpg
#   inflating: /home/ubuntu/data/training/Zhang_Ziyi_11.jpg
#   inflating: /home/ubuntu/data/training/Zhang_Ziyi_12.jpg
#   inflating: /home/ubuntu/data/training/Zhang_Ziyi_20.jpg
#   inflating: /home/ubuntu/data/training/Zhang_Ziyi_21.jpg
#   inflating: /home/ubuntu/data/training/Zhang_Ziyi_22.jpg
#   inflating: /home/ubuntu/data/training/Zhang_Ziyi_40.jpg
#   inflating: /home/ubuntu/data/training/Zhang_Ziyi_41.jpg
#   inflating: /home/ubuntu/data/training/Zhang_Ziyi_42.jpg
#   inflating: /home/ubuntu/data/training/Zhong_Nanshan_00.jpg
#   inflating: /home/ubuntu/data/training/Zhong_Nanshan_01.jpg
#   inflating: /home/ubuntu/data/training/Zhong_Nanshan_02.jpg
#   inflating: /home/ubuntu/data/training/Zhong_Nanshan_10.jpg
#   inflating: /home/ubuntu/data/training/Zhong_Nanshan_11.jpg
#   inflating: /home/ubuntu/data/training/Zhong_Nanshan_12.jpg
#   inflating: /home/ubuntu/data/training/Zhong_Nanshan_50.jpg
#   inflating: /home/ubuntu/data/training/Zhong_Nanshan_51.jpg
#   inflating: /home/ubuntu/data/training/Zhong_Nanshan_52.jpg
#   inflating: /home/ubuntu/data/training_frames_keypoints.csv

# %% [markdown]
# <div class="alert alert-info">**Note:** Workspaces automatically close connections after 30 minutes of inactivity (including inactivity while training!). Use the code snippet below to keep your workspace alive during training. (The active_session context manager is imported below.)
# </div>
# ```
# from workspace_utils import active_session
#
# with active_session():
#     train_model(num_epochs)
# ```

# %%
# import the usual resources
import matplotlib.pyplot as plt
import numpy as np

# import utilities to keep workspaces alive during model training
from workspace_utils import active_session

# watch for any changes in model.py, if it changes, re-load it automatically
# %load_ext autoreload
# %autoreload 2

# %%
## TODO: Define the Net in models.py

import torch
import torch.nn as nn
import torch.nn.functional as F

## TODO: Once you've define the network, you can instantiate it
# one example conv layer has been provided for you
from models import Net

net = Net()
print(net)
# Out:
# Net(
#   (conv1): Conv2d(1, 32, kernel_size=(5, 5), stride=(1, 1))
#   (conv1_bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1))
#   (conv2_bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1))
#   (conv3_bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv4): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1))
#   (conv4_bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv5): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1))
#   (conv5_bn): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc_1): Linear(in_features=12800, out_features=1024, bias=True)
#   (fc1_bn): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc_2): Linear(in_features=1024, out_features=136, bias=True)
#   (dropout): Dropout(p=0.3)
# )

# %% [markdown]
# ## Transform the dataset
#
# To prepare for training, create a transformed dataset of images and keypoints.
#
# ### TODO: Define a data transform
#
# In PyTorch, a convolutional neural network expects a torch image of a consistent size as input. For efficient training, and so your model's loss does not blow up during training, it is also suggested that you normalize the input images and keypoints. The necessary transforms have been defined in `data_load.py` and you **do not** need to modify these; take a look at this file (you'll see the same transforms that were defined and applied in Notebook 1).
#
# To define the data transform below, use a [composition](http://pytorch.org/tutorials/beginner/data_loading_tutorial.html#compose-transforms) of:
# 1. Rescaling and/or cropping the data, such that you are left with a square image (the suggested size is 224x224px)
# 2. Normalizing the images and keypoints; turning each RGB image into a grayscale image with a color range of [0, 1] and transforming the given keypoints into a range of [-1, 1]
# 3. Turning these images and keypoints into Tensors
#
# These transformations have been defined in `data_load.py`, but it's up to you to call them and create a `data_transform` below. **This transform will be applied to the training data and, later, the test data**. It will change how you go about displaying these images and keypoints, but these steps are essential for efficient training.
#
# As a note, should you want to perform data augmentation (which is optional in this project), and randomly rotate or shift these images, a square image size will be useful; rotating a 224x224 image by 90 degrees will result in the same shape of output.

# %%
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils

# the dataset we created in Notebook 1 is copied in the helper file `data_load.py`
from data_load import FacialKeypointsDataset
# the transforms we defined in Notebook 1 are in the helper file `data_load.py`
from data_load import Rescale, RandomCrop, Normalize, ToTensor


## TODO: define the data_transform using transforms.Compose([all tx's, . , .])
# order matters! i.e. rescaling should come before a smaller crop
data_transform = transforms.Compose([Rescale(250),
                                     RandomCrop(224),
                                     Normalize(), 
                                     ToTensor()])

# testing that you've defined a transform
assert(data_transform is not None), 'Define a data_transform'

# %%
# create the transformed dataset
transformed_dataset = FacialKeypointsDataset(csv_file='/home/ubuntu/data/training_frames_keypoints.csv',
                                             root_dir='/home/ubuntu/data/training/',
                                             transform=data_transform)


print('Number of images: ', len(transformed_dataset))

# iterate through the transformed dataset and print some stats about the first few samples
for i in range(4):
    sample = transformed_dataset[i]
    print(i, sample['image'].size(), sample['keypoints'].size())
# Out:
# Number of images:  3462
# 0 torch.Size([1, 224, 224]) torch.Size([68, 2])
# 1 torch.Size([1, 224, 224]) torch.Size([68, 2])
# 2 torch.Size([1, 224, 224]) torch.Size([68, 2])
# 3 torch.Size([1, 224, 224]) torch.Size([68, 2])

# %% [markdown]
# ## Batching and loading data
#
# Next, having defined the transformed dataset, we can use PyTorch's DataLoader class to load the training data in batches of whatever size as well as to shuffle the data for training the model. You can read more about the parameters of the DataLoader, in [this documentation](http://pytorch.org/docs/master/data.html).
#
# #### Batch size
# Decide on a good batch size for training your model. Try both small and large batch sizes and note how the loss decreases as the model trains. Too large a batch size may cause your model to crash and/or run out of memory while training.
#
# **Note for Windows users**: Please change the `num_workers` to 0 or you may face some issues with your DataLoader failing.

# %%
# load training data in batches
batch_size = 32

train_loader = DataLoader(transformed_dataset, 
                          batch_size=batch_size,
                          shuffle=True, 
                          num_workers=4)

# %% [markdown]
# ## Before training
#
# Take a look at how this model performs before it trains. You should see that the keypoints it predicts start off in one spot and don't match the keypoints on a face at all! It's interesting to visualize this behavior so that you can compare it to the model after training and see how the model has improved.
#
# #### Load in the test dataset
#
# The test dataset is one that this model has *not* seen before, meaning it has not trained with these images. We'll load in this test data and before and after training, see how your model performs on this set!
#
# To visualize this test data, we have to go through some un-transformation steps to turn our images into python images from tensors and to turn our keypoints back into a recognizable range.

# %%
# load in the test data, using the dataset class
# AND apply the data_transform you defined above

# create the test dataset
test_dataset = FacialKeypointsDataset(csv_file='/home/ubuntu/data/test_frames_keypoints.csv',
                                             root_dir='/home/ubuntu/data/test/',
                                             transform=data_transform)

# %%
# load test data in batches
batch_size = 32

test_loader = DataLoader(test_dataset, 
                          batch_size=batch_size,
                          shuffle=True, 
                          num_workers=4)

# %% [markdown]
# ## Apply the model on a test sample
#
# To test the model on a test sample of data, you have to follow these steps:
# 1. Extract the image and ground truth keypoints from a sample
# 2. Wrap the image in a Variable, so that the net can process it as input and track how it changes as the image moves through the network.
# 3. Make sure the image is a FloatTensor, which the model expects.
# 4. Forward pass the image through the net to get the predicted, output keypoints.
#
# This function test how the network performs on the first batch of test data. It returns the images, the transformed images, the predicted keypoints (produced by the model), and the ground truth keypoints.

# %%
# test the model on a batch of test images

def net_sample_output():
    
    # iterate through the test dataset
    for i, sample in enumerate(test_loader):
        
        # get sample data: images and ground truth keypoints
        images = sample['image']
        key_pts = sample['keypoints']

        # convert images to FloatTensors
        images = images.type(torch.FloatTensor)

        # forward pass to get net output
        output_pts = net(images)
        
        # reshape to batch_size x 68 x 2 pts
        output_pts = output_pts.view(output_pts.size()[0], 68, -1)
        
        # break after first image is tested
        if i == 0:
            return images, output_pts, key_pts

# %% [markdown]
# #### Debugging tips
#
# If you get a size or dimension error here, make sure that your network outputs the expected number of keypoints! Or if you get a Tensor type error, look into changing the above code that casts the data into float types: `images = images.type(torch.FloatTensor)`.

# %%
# call the above function
# returns: test images, test predicted keypoints, test ground truth keypoints
test_images, test_outputs, gt_pts = net_sample_output()

# print out the dimensions of the data to see if they make sense
print(test_images.data.size())
print(test_outputs.data.size())
print(gt_pts.size())
# Out:
# torch.Size([32, 1, 224, 224])
# torch.Size([32, 68, 2])
# torch.Size([32, 68, 2])

# %% [markdown]
# ## Visualize the predicted keypoints
#
# Once we've had the model produce some predicted output keypoints, we can visualize these points in a way that's similar to how we've displayed this data before, only this time, we have to "un-transform" the image/keypoint data to display it.
#
# Note that I've defined a *new* function, `show_all_keypoints` that displays a grayscale image, its predicted keypoints and its ground truth keypoints (if provided).

# %%
def show_all_keypoints(image, predicted_key_pts, gt_pts=None):
    """Show image with predicted keypoints"""
    # image is grayscale
    plt.imshow(image, cmap='gray')
    plt.scatter(predicted_key_pts[:, 0], predicted_key_pts[:, 1], s=20, marker='.', c='m')
    # plot ground truth points as green pts
    if gt_pts is not None:
        plt.scatter(gt_pts[:, 0], gt_pts[:, 1], s=20, marker='.', c='g')

# %% [markdown]
# #### Un-transformation
#
# Next, you'll see a helper function. `visualize_output` that takes in a batch of images, predicted keypoints, and ground truth keypoints and displays a set of those images and their true/predicted keypoints.
#
# This function's main role is to take batches of image and keypoint data (the input and output of your CNN), and transform them into numpy images and un-normalized keypoints (x, y) for normal display. The un-transformation process turns keypoints and images into numpy arrays from Tensors *and* it undoes the keypoint normalization done in the Normalize() transform; it's assumed that you applied these transformations when you loaded your test data.

# %%
# visualize the output
# by default this shows a batch of 10 images
def visualize_output(test_images, test_outputs, gt_pts=None, batch_size=10):

    for i in range(batch_size):
        plt.figure(figsize=(20,10))
        ax = plt.subplot(1, batch_size, i+1)

        # un-transform the image data
        image = test_images[i].data   # get the image from it's Variable wrapper
        image = image.numpy()   # convert to numpy array from a Tensor
        image = np.transpose(image, (1, 2, 0))   # transpose to go from torch to numpy image

        # un-transform the predicted key_pts data
        predicted_key_pts = test_outputs[i].data
        predicted_key_pts = predicted_key_pts.numpy()
        # undo normalization of keypoints  
        predicted_key_pts = predicted_key_pts*50.0+100
        
        # plot ground truth points for comparison, if they exist
        ground_truth_pts = None
        if gt_pts is not None:
            ground_truth_pts = gt_pts[i]         
            ground_truth_pts = ground_truth_pts*50.0+100
        
        # call show_all_keypoints
        show_all_keypoints(np.squeeze(image), predicted_key_pts, ground_truth_pts)
            
        plt.axis('off')

    plt.show()
    
# call it
visualize_output(test_images, test_outputs, gt_pts)

# %% [markdown]
# ## Training
#
# #### Loss function
# Training a network to predict keypoints is different than training a network to predict a class; instead of outputting a distribution of classes and using cross entropy loss, you may want to choose a loss function that is suited for regression, which directly compares a predicted value and target value. Read about the various kinds of loss functions (like MSE or L1/SmoothL1 loss) in [this documentation](http://pytorch.org/docs/master/_modules/torch/nn/modules/loss.html).
#
# ### TODO: Define the loss and optimization
#
# Next, you'll define how the model will train by deciding on the loss function and optimizer.
#
# ---

# %%
## TODO: Define the loss and optimization
import torch.optim as optim

criterion = nn.SmoothL1Loss()
#criterion = nn.MSELoss()

optimizer = optim.Adam(net.parameters(), lr=1.1e-4)

# %% [markdown]
# ## Training and Initial Observation
#
# Now, you'll train on your batched training data from `train_loader` for a number of epochs.
#
# To quickly observe how your model is training and decide on whether or not you should modify it's structure or hyperparameters, you're encouraged to start off with just one or two epochs at first. As you train, note how your the model's loss behaves over time: does it decrease quickly at first and then slow down? Does it take a while to decrease in the first place? What happens if you change the batch size of your training data or modify your loss function? etc.
#
# Use these initial observations to make changes to your model and decide on the best architecture before you train for many epochs and create a final model.

# %%
def train_net(n_epochs):

    # prepare the net for training
    net.train()

    for epoch in range(n_epochs):  # loop over the dataset multiple times
        
        running_loss = 0.0

        # train on batches of data, assumes you already have train_loader
        for batch_i, data in enumerate(train_loader):
            # get the input images and their corresponding labels
            images = data['image']
            key_pts = data['keypoints']

            # flatten pts
            key_pts = key_pts.view(key_pts.size(0), -1)

            # convert variables to floats for regression loss
            key_pts = key_pts.type(torch.FloatTensor)
            images = images.type(torch.FloatTensor)

            # forward pass to get outputs
            output_pts = net(images)

            # calculate the loss between predicted and target keypoints
            loss = criterion(output_pts, key_pts)

            # zero the parameter (weight) gradients
            optimizer.zero_grad()
            
            # backward pass to calculate the weight gradients
            loss.backward()

            # update the weights
            optimizer.step()

            # print loss statistics
            running_loss += loss.item()
            if batch_i % 10 == 9:    # print every 10 batches
                print('Epoch: {}, Batch: {}, Avg. Loss: {}'.format(epoch + 1, batch_i+1, running_loss/10))
                running_loss = 0.0

    print('Finished Training')

# %%
# train your network
n_epochs = 10 # start small, and increase when you've decided on your model structure and hyperparams

# this is a Workspaces-specific context manager to keep the connection
# alive while training your model, not part of pytorch
with active_session():
    train_net(n_epochs)
# Out:
# Epoch: 1, Batch: 10, Avg. Loss: 0.2611238479614258
# Epoch: 1, Batch: 20, Avg. Loss: 0.18437842577695845
# Epoch: 1, Batch: 30, Avg. Loss: 0.13597531765699386
# Epoch: 1, Batch: 40, Avg. Loss: 0.10249297022819519
# Epoch: 1, Batch: 50, Avg. Loss: 0.08093675673007965
# Epoch: 1, Batch: 60, Avg. Loss: 0.06024673469364643
# Epoch: 1, Batch: 70, Avg. Loss: 0.06040312796831131
# Epoch: 1, Batch: 80, Avg. Loss: 0.06702112331986428
# Epoch: 1, Batch: 90, Avg. Loss: 0.05387818589806557
# Epoch: 1, Batch: 100, Avg. Loss: 0.054034705460071566
# Epoch: 2, Batch: 10, Avg. Loss: 0.053946754708886144
# Epoch: 2, Batch: 20, Avg. Loss: 0.05395141430199146
# Epoch: 2, Batch: 30, Avg. Loss: 0.05674428455531597
# Epoch: 2, Batch: 40, Avg. Loss: 0.04881734419614077
# Epoch: 2, Batch: 50, Avg. Loss: 0.046673692762851715
# Epoch: 2, Batch: 60, Avg. Loss: 0.04357495717704296
# Epoch: 2, Batch: 70, Avg. Loss: 0.04343713149428367
# Epoch: 2, Batch: 80, Avg. Loss: 0.04556872770190239
# Epoch: 2, Batch: 90, Avg. Loss: 0.04087722543627024
# Epoch: 2, Batch: 100, Avg. Loss: 0.042087812907993793
# Epoch: 3, Batch: 10, Avg. Loss: 0.05630872808396816
# Epoch: 3, Batch: 20, Avg. Loss: 0.04273773077875376
# Epoch: 3, Batch: 30, Avg. Loss: 0.03911469019949436
# Epoch: 3, Batch: 40, Avg. Loss: 0.04104248825460673
# Epoch: 3, Batch: 50, Avg. Loss: 0.04241676349192858
# Epoch: 3, Batch: 60, Avg. Loss: 0.034576164186000825
# Epoch: 3, Batch: 70, Avg. Loss: 0.03617889173328877
# Epoch: 3, Batch: 80, Avg. Loss: 0.04219551049172878
# Epoch: 3, Batch: 90, Avg. Loss: 0.03352147508412599
# Epoch: 3, Batch: 100, Avg. Loss: 0.03981130309402943
# Epoch: 4, Batch: 10, Avg. Loss: 0.03436322323977947
# Epoch: 4, Batch: 20, Avg. Loss: 0.03579501025378704
# Epoch: 4, Batch: 30, Avg. Loss: 0.03979746028780937
# Epoch: 4, Batch: 40, Avg. Loss: 0.04124025069177151
# Epoch: 4, Batch: 50, Avg. Loss: 0.03772995006293058
# Epoch: 4, Batch: 60, Avg. Loss: 0.039009323716163634
# Epoch: 4, Batch: 70, Avg. Loss: 0.03333854991942644
# Epoch: 4, Batch: 80, Avg. Loss: 0.037462223693728446
# Epoch: 4, Batch: 90, Avg. Loss: 0.03161652367562055
# Epoch: 4, Batch: 100, Avg. Loss: 0.03413676004856825
# Epoch: 5, Batch: 10, Avg. Loss: 0.03618976939469576
# Epoch: 5, Batch: 20, Avg. Loss: 0.03566205911338329
# Epoch: 5, Batch: 30, Avg. Loss: 0.03308636117726564
# Epoch: 5, Batch: 40, Avg. Loss: 0.04563440605998039
# Epoch: 5, Batch: 50, Avg. Loss: 0.030743067897856236
# Epoch: 5, Batch: 60, Avg. Loss: 0.028712068125605582
# Epoch: 5, Batch: 70, Avg. Loss: 0.03275758493691683
# Epoch: 5, Batch: 80, Avg. Loss: 0.028291666693985463
# Epoch: 5, Batch: 90, Avg. Loss: 0.03203949723392725
# Epoch: 5, Batch: 100, Avg. Loss: 0.0327391279861331
# Epoch: 6, Batch: 10, Avg. Loss: 0.027887929044663907
# Epoch: 6, Batch: 20, Avg. Loss: 0.035416107065975665
# Epoch: 6, Batch: 30, Avg. Loss: 0.028923537209630014
# Epoch: 6, Batch: 40, Avg. Loss: 0.03204071782529354
# Epoch: 6, Batch: 50, Avg. Loss: 0.028017038851976393
# Epoch: 6, Batch: 60, Avg. Loss: 0.02920409869402647
# Epoch: 6, Batch: 70, Avg. Loss: 0.024196402356028556
# Epoch: 6, Batch: 80, Avg. Loss: 0.038623339496552944
# Epoch: 6, Batch: 90, Avg. Loss: 0.030266563408076763
# Epoch: 6, Batch: 100, Avg. Loss: 0.03320589382201433
# Epoch: 7, Batch: 10, Avg. Loss: 0.03306908886879682
# Epoch: 7, Batch: 20, Avg. Loss: 0.03753171619027853
# Epoch: 7, Batch: 30, Avg. Loss: 0.03335522525012493
# Epoch: 7, Batch: 40, Avg. Loss: 0.025669670291244985
# Epoch: 7, Batch: 50, Avg. Loss: 0.02385681923478842
# Epoch: 7, Batch: 60, Avg. Loss: 0.023652015440165996
# Epoch: 7, Batch: 70, Avg. Loss: 0.024176870100200178
# Epoch: 7, Batch: 80, Avg. Loss: 0.026572702452540398
# Epoch: 7, Batch: 90, Avg. Loss: 0.028313855081796645
# Epoch: 7, Batch: 100, Avg. Loss: 0.026951103657484054
# Epoch: 8, Batch: 10, Avg. Loss: 0.02808273956179619
# Epoch: 8, Batch: 20, Avg. Loss: 0.03140906151384115
# Epoch: 8, Batch: 30, Avg. Loss: 0.027810187824070454
# Epoch: 8, Batch: 40, Avg. Loss: 0.024568556807935238
# Epoch: 8, Batch: 50, Avg. Loss: 0.02605965528637171
# Epoch: 8, Batch: 60, Avg. Loss: 0.03024196606129408
# Epoch: 8, Batch: 70, Avg. Loss: 0.024373715557157994
# Epoch: 8, Batch: 80, Avg. Loss: 0.0268147861585021
# Epoch: 8, Batch: 90, Avg. Loss: 0.029450636729598044
# Epoch: 8, Batch: 100, Avg. Loss: 0.021507658623158933
# Epoch: 9, Batch: 10, Avg. Loss: 0.025932195782661437
# Epoch: 9, Batch: 20, Avg. Loss: 0.03373176921159029
# Epoch: 9, Batch: 30, Avg. Loss: 0.02314272429794073
# Epoch: 9, Batch: 40, Avg. Loss: 0.02229501623660326
# Epoch: 9, Batch: 50, Avg. Loss: 0.021555190812796353
# Epoch: 9, Batch: 60, Avg. Loss: 0.028853839449584483
# Epoch: 9, Batch: 70, Avg. Loss: 0.019865082763135433
# Epoch: 9, Batch: 80, Avg. Loss: 0.023008650448173285
# Epoch: 9, Batch: 90, Avg. Loss: 0.020498296525329352
# Epoch: 9, Batch: 100, Avg. Loss: 0.021679770946502686
# Epoch: 10, Batch: 10, Avg. Loss: 0.01944578196853399
# Epoch: 10, Batch: 20, Avg. Loss: 0.02493896409869194
# Epoch: 10, Batch: 30, Avg. Loss: 0.021083527337759735
# Epoch: 10, Batch: 40, Avg. Loss: 0.030503996275365354
# Epoch: 10, Batch: 50, Avg. Loss: 0.022069112211465836
# Epoch: 10, Batch: 60, Avg. Loss: 0.022118134051561357
# Epoch: 10, Batch: 70, Avg. Loss: 0.018382953945547342
# Epoch: 10, Batch: 80, Avg. Loss: 0.021634542476385833
# Epoch: 10, Batch: 90, Avg. Loss: 0.028729433193802834
# Epoch: 10, Batch: 100, Avg. Loss: 0.026607449632138014
# Finished Training

# %% [markdown]
# ## Test data
#
# See how your model performs on previously unseen, test data. We've already loaded and transformed this data, similar to the training data. Next, run your trained model on these images to see what kind of keypoints are produced. You should be able to see if your model is fitting each new face it sees, if the points are distributed randomly, or if the points have actually overfitted the training data and do not generalize.

# %%
# get a sample of test data again
test_images, test_outputs, gt_pts = net_sample_output()

print(test_images.data.size())
print(test_outputs.data.size())
print(gt_pts.size())
# Out:
# torch.Size([32, 1, 224, 224])
# torch.Size([32, 68, 2])
# torch.Size([32, 68, 2])

# %%
## TODO: visualize your test output
# you can use the same function as before, by un-commenting the line below:

visualize_output(test_images, test_outputs, gt_pts)

# %% [markdown]
# Once you've found a good model (or two), save your model so you can load it and use it later!
#
# Save your models but please **delete any checkpoints and saved models before you submit your project** otherwise your workspace may be too large to submit.

# %%
## TODO: change the name to something uniqe for each new model
model_dir = 'saved_models/'
model_name = 'keypoints_model_epoch_10.pt'

# after training, save your model parameters in the dir 'saved_models'
torch.save(net.state_dict(), model_dir+model_name)

# %% [markdown]
# After you've trained a well-performing model, answer the following questions so that we have some insight into your training and architecture selection process. Answering all questions is required to pass this project.

# %% [markdown]
# ### Question 1: What optimization and loss functions did you choose and why?

# %% [markdown]
# **Answer**: For optimization I have used Adam as it yields the best result in most of the available optimizer, and for loass function I have used L1Smooth as it is less sensitive to the outliers than other regression loss as MSE, L2 loss.

# %% [markdown]
# ### Question 2: What kind of network architecture did you start with and how did it change as you tried different architectures? Did you decide to add more convolutional layers or any layers to avoid overfitting the data?

# %% [markdown]
# **Answer**: I have started with 5 convolutional layers with batch normalization to avoid overfitting. I had tried with fewer layers, although the results were not satisfactory.

# %% [markdown]
# ### Question 3: How did you decide on the number of epochs and batch_size to train your model?

# %% [markdown]
# **Answer**: I have used batch size in multiples of 8, batch size 16 was oscillating around .09 to .03, batch size 64 was computationally expensive, so batch size 32 was appropriate. I decided to use 10 epochs as the change is approximately similar for each epoch after first few epochs.

# %% [markdown]
# ## Feature Visualization
#
# Sometimes, neural networks are thought of as a black box, given some input, they learn to produce some output. CNN's are actually learning to recognize a variety of spatial patterns and you can visualize what each convolutional layer has been trained to recognize by looking at the weights that make up each convolutional kernel and applying those one at a time to a sample image. This technique is called feature visualization and it's useful for understanding the inner workings of a CNN.

# %% [markdown]
# In the cell below, you can see how to extract a single filter (by index) from your first convolutional layer. The filter should appear as a grayscale grid.

# %%
# Get the weights in the first conv layer, "conv1"
# if necessary, change this to reflect the name of your first conv layer
weights1 = net.conv1.weight.data

w = weights1.numpy()

filter_index = 0

print(w[filter_index][0])
print(w[filter_index][0].shape)

# display the filter weights
plt.imshow(w[filter_index][0], cmap='gray')
# Out:
# [[ 0.04474645  0.16974273 -0.19088809 -0.09588166 -0.05648423]
#  [-0.06049772  0.1556384   0.1619018   0.12497779  0.01929054]
#  [ 0.13092533  0.19050013  0.01568663  0.138758   -0.16173443]
#  [ 0.04493596 -0.04364686  0.01210962  0.08717328  0.0466872 ]
#  [ 0.15618517 -0.10611099  0.20234346 -0.17316522  0.11501288]]
# (5, 5)

# %% [markdown]
# ## Feature maps
#
# Each CNN has at least one convolutional layer that is composed of stacked filters (also known as convolutional kernels). As a CNN trains, it learns what weights to include in it's convolutional kernels and when these kernels are applied to some input image, they produce a set of **feature maps**. So, feature maps are just sets of filtered images; they are the images produced by applying a convolutional kernel to an input image. These maps show us the features that the different layers of the neural network learn to extract. For example, you might imagine a convolutional kernel that detects the vertical edges of a face or another one that detects the corners of eyes. You can see what kind of features each of these kernels detects by applying them to an image. One such example is shown below; from the way it brings out the lines in an the image, you might characterize this as an edge detection filter.
#
# <img src='images/feature_map_ex.png' width=50% height=50%/>
#
#
# Next, choose a test image and filter it with one of the convolutional kernels in your trained CNN; look at the filtered output to get an idea what that particular kernel detects.
#
# ### TODO: Filter an image to see the effect of a convolutional kernel
# ---

# %%
##TODO: load in and display any image from the transformed test dataset

## TODO: Using cv's filter2D function,
## apply a specific set of filter weights (like the one displayed above) to the test image
import cv2

image = test_dataset[20]
image = image['image'].numpy().reshape(224, 224)

#image = cv2.imread('./images/straw_hat.png')
i#mage_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

filtered_image = cv2.filter2D(image, -1, w[1][0])

plt.imshow(filtered_image, cmap='gray')

# %%
image = test_dataset[20]
image['image'].numpy().reshape(224, 224)
# Out:
# array([[ 0.54901961,  0.55294118,  0.55686275, ...,  0.31764706,
#          0.31764706,  0.30980392],
#        [ 0.54901961,  0.55294118,  0.55686275, ...,  0.30980392,
#          0.30196078,  0.29411765],
#        [ 0.54901961,  0.55294118,  0.55686275, ...,  0.30196078,
#          0.28627451,  0.27843137],
#        ...,
#        [ 0.2       ,  0.2       ,  0.18823529, ...,  0.23137255,
#          0.23137255,  0.23529412],
#        [ 0.32156863,  0.32156863,  0.29803922, ...,  0.22745098,
#          0.23137255,  0.23529412],
#        [ 0.39607843,  0.43529412,  0.43529412, ...,  0.22745098,
#          0.23137255,  0.23529412]])

# %% [markdown]
# ### Question 4: Choose one filter from your trained CNN and apply it to a test image; what purpose do you think it plays? What kind of feature do you think it detects?

# %% [markdown]
# **Answer**:
# I think this filter plays a role to detect lines on faces in the image pretty well.

# %% [markdown]
# ---
# ## Moving on!
#
# Now that you've defined and trained your model (and saved the best model), you are ready to move on to the last notebook, which combines a face detector with your saved model to create a facial keypoint detection system that can predict the keypoints on *any* face in an image!
